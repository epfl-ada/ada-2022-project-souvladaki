# %% [markdown]
# # Initial Analysis
# This notebook contains the initial analysis and preprocessing of Wikispeedia graph. We perform the following tasks:
# - We load the files
# - We process the data to create the graph representation
# - We perform an analysis over the paths, both succesful and failed
# - We study the link structure and position through BeatifulSoup
# - We present multiple statistical results

# %%
# Generally needed libraries

import pandas as pd
import networkx as nx
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Graph Analysis
#
# In this section we start our basic analysis by creating a graph representation of the data and by running graph analytics and visualization functions.

# %%
# Loading the data, by skipping the first descriptive rows. Note that we could also use
# the parameter "comment=#" to dodge unecessary data.

articles = pd.read_table("data/graph/articles.tsv", skiprows=11, names=["article"])

categories = pd.read_csv(
    "data/graph/categories.tsv", skiprows=12, sep="\t", names=["article", "category"]
)

links = pd.read_csv(
    "data/graph/links.tsv", skiprows=11, sep="\t", names=["article1", "article2"]
)

# %%
# Creating the graph representation in a dataframe

wiki_graph = pd.DataFrame(columns=["article", "category", "outlinks", "outlinks_count", "inlinks_count"])

# Adding all articles. This could also be used as index.
wiki_graph["article"] = articles["article"]

wiki_graph["outlinks"] = [list() for x in range(len(wiki_graph.index))]
wiki_graph["inlinks_count"] = [0 for x in range(len(wiki_graph.index))]

# Add to each article entry its categories as a list
grouped_categories = categories.groupby("article")
for entry in grouped_categories:
    article_name = entry[0]
    cats_df = entry[1]["category"]
    cats_list = cats_df.values.tolist()

    indices = wiki_graph.index[wiki_graph["article"] == article_name].tolist()
    for i in indices:
        wiki_graph.at[i, "category"] = cats_list


# Add to each article entry its links as a list.
grouped_links = links.groupby("article1")
for entry in grouped_links:
    article_name = entry[0]
    links_df = entry[1]["article2"]
    links_list = links_df.values.tolist()

    # Add all links to article 1
    indices = wiki_graph.index[wiki_graph["article"] == article_name].tolist()
    for i in indices:
        previous_list = list(wiki_graph.at[i, "outlinks"])
        new_list = previous_list + links_list
        wiki_graph.at[i, "outlinks"] = new_list

    for link in links_list:
        article2 = link
        article2_index = wiki_graph.index[wiki_graph["article"] == article2].tolist()
        for i in article2_index:
            wiki_graph.at[i, "inlinks_count"] = wiki_graph.at[i, "inlinks_count"] + 1

# Add to each article how many links it has
wiki_graph["outlinks_count"] = wiki_graph["outlinks"].apply(lambda x: len(x))

# Check
wiki_graph.tail(5)
# Out:
#            article                                           category  \
# 4599       Zionism  [subject.People.Political_People, subject.Reli...
# 4600     Zirconium      [subject.Science.Chemistry.Chemical_elements]
# 4601     Zoroaster     [subject.People.Religious_figures_and_leaders]
# 4602  Zuid-Gelders  [subject.Geography.European_Geography, subject...
# 4603          Zulu              [subject.Geography.African_Geography]
#
#                                                outlinks  outlinks_count  \
# 4599  [18th_century, 19th_century, Adolf_Hitler, Alb...              74
# 4600  [Aluminium, Arabic_language, Australia, Bicycl...              42
# 4601  [18th_century, 9th_century, Afghanistan, Age_o...              28
# 4602  [Brabantian, Dutch_language, East_Flemish, Hol...               5
# 4603  [AK-47, Bantu, Cape_Town, Christianity, Englis...              15
#
#       inlinks_count
# 4599             25
# 4600             15
# 4601              9
# 4602              5
# 4603             14

# %%
assert wiki_graph.shape[0] == 4604
assert wiki_graph["article"].is_unique 
assert wiki_graph["article"].isnull().values.any() == False

# %%
wiki_graph = wiki_graph[(wiki_graph["outlinks_count"] > 0) | (wiki_graph["inlinks_count"] > 0)]

# %%
# Validation and basic checks and graph statistics
print("Is articles unique in the dataframe?", wiki_graph["article"].is_unique)
print("How many articles are in the data?", len(wiki_graph))
print("Graph shape", wiki_graph.shape)

print()

print("Are there NULL values in articles?", wiki_graph["article"].isnull().values.any())
print(
    "Are there NULL values in categories?", wiki_graph["category"].isnull().values.any()
)
# Out:
# Is articles unique in the dataframe? True
# How many articles are in the data? 4592
# Graph shape (4592, 5)
#
# Are there NULL values in articles? False
# Are there NULL values in categories? True

# %%
# We proceed with some graph analytics and visualizations.
# Here, we provide some profound helper functions to generate graphs using networkX


def generate_nx_from_wiki(wiki_graph):
    """Generate a networkx graph from Wikispeedia graph dataframe.

    Args:
        wiki_graph (_type_): Wikispeedia graph dataframe

    Raises:
        ValueError: If it exists a link that has no other links

    Returns:
        _type_: A networkX graph Object
    """
    #G = nx.Graph()
    G = nx.DiGraph()
    sampled_wiki_graph = wiki_graph
    for ind in sampled_wiki_graph.index:
        node_name = wiki_graph["article"][ind]
        node_links = wiki_graph["outlinks"][ind]
        node_links_count = wiki_graph["outlinks_count"][ind]

        #if len(node_links) == 0:
        #    raise ValueError

        for l in node_links:
            G.add_edge(node_name, l)

    return G


def graph_report(G):
    """Prints some graph analytics stuff about a graph

    Args:
        G (_type_): NetworkX graph
    """
    print("Total number of nodes: " + str(G.number_of_nodes()))
    print("Total number of edges: " + str(G.number_of_edges()))

    #print(
    ##    "Number of different connected components (directly linked nodes): "
    #    + str(len(list(nx.strongly_connected_components(G))))
    #)

    #for component_index in range(len(list(nx.strongly_connected_components(G)))):
    #    print(
    #        "Number of nodes in the",
    #        component_index,
    #        " subgroup: " + str(len(list(nx.strongly_connected_components(G))[component_index])),
    #    )

# %%
# Checking the structure of the graph
G = generate_nx_from_wiki(wiki_graph)
graph_report(G)

# We see that three nodes all over the graph form a disconnected comp: ['Friend_Directdebit', 'Directdebit', 'Sponsorship_Directdebit']
# This an actual thing in the provided data (Maybe because of the link removal done in Wikispeedia)
#nodes_disc_comp = list(list(nx.strongly_connected_components(G))[1])
#print("The disconnected nodes are:", nodes_disc_comp)

# Removing the disconnected nodes from graph
#for node in nodes_disc_comp:
#    wiki_graph = wiki_graph[wiki_graph["article"] != node]

# Checking the structure of the final graph
#print("\n>> After node removal")
#G = generate_nx_from_wiki(wiki_graph)
#graph_report(G)
# Out:
# Total number of nodes: 4592
# Total number of edges: 119882

# %%
# Drawing the graph. Naive drawing does not give much insight, but it is interesting to see
# how the graph looks like.
nx.draw(G, with_labels=False, node_size=0.5)
plt.draw()
# Out:
# Error in callback <function flush_figures at 0x12ca51750> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/Library/Python/3.10/lib/python/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~/Library/Python/3.10/lib/python/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/backend_bases.py:2290, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2284     renderer = _get_renderer(
#    2285         self.figure,
#    2286         functools.partial(
#    2287             print_method, orientation=orientation)
#    2288     )
#    2289     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2290         self.figure.draw(renderer)
#    2292 if bbox_inches:
#    2293     if bbox_inches == "tight":
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/figure.py:2803, in Figure.draw(self, renderer)
#    2800         # ValueError can occur when resizing a window.
#    2802 self.patch.draw(renderer)
# -> 2803 mimage._draw_list_compositing_images(
#    2804     renderer, self, artists, self.suppressComposite)
#    2806 for sfig in self.subfigs:
#    2807     sfig.draw(renderer)
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/patches.py:4485, in FancyArrowPatch.draw(self, renderer)
#    4478 with self._bind_draw_path_function(renderer) as draw_path:
#    4479
#    4480     # FIXME : dpi_cor is for the dpi-dependency of the linewidth. There
#    4481     # could be room for improvement.  Maybe _get_path_in_displaycoord
#    4482     # could take a renderer argument, but get_path should be adapted
#    4483     # too.
#    4484     self._dpi_cor = renderer.points_to_pixels(1.)
# -> 4485     path, fillable = self._get_path_in_displaycoord()
#    4487     if not np.iterable(fillable):
#    4488         path = [path]
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/patches.py:4453, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4451     posB = self._convert_xy_units(self._posA_posB[1])
#    4452     (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4453     _path = self.get_connectionstyle()(posA, posB,
#    4454                                        patchA=self.patchA,
#    4455                                        patchB=self.patchB,
#    4456                                        shrinkA=self.shrinkA * dpi_cor,
#    4457                                        shrinkB=self.shrinkB * dpi_cor
#    4458                                        )
#    4459 else:
#    4460     _path = self.get_transform().transform_path(self._path_original)
#
# File /opt/homebrew/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:774, in draw_networkx_edges.<locals>._draw_networkx_edges_fancy_arrow_patch.<locals>._connectionstyle(posA, posB, *args, **kwargs)
#     771     ret = mpl.path.Path(ax.transData.transform(path), [1, 4, 4, 4, 4, 4, 4])
#     772 # if not, fall back to the user specified behavior
#     773 else:
# --> 774     ret = base_connection_style(posA, posB, *args, **kwargs)
#     776 return ret
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/patches.py:2771, in ConnectionStyle._Base.__call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2769 path = self.connect(posA, posB)
#    2770 clipped_path = self._clip(path, patchA, patchB)
# -> 2771 shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2772 return shrunk_path
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/patches.py:2758, in ConnectionStyle._Base._shrink(self, path, shrinkA, shrinkB)
#    2756 insideB = inside_circle(*path.vertices[-1], shrinkB)
#    2757 try:
# -> 2758     path, right = split_path_inout(path, insideB)
#    2759 except ValueError:
#    2760     pass
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/bezier.py:371, in split_path_inout(path, inside, tolerance, reorder_inout)
#     368     raise ValueError("The path does not intersect with the patch")
#     370 bp = bezier_path.reshape((-1, 2))
# --> 371 left, right = split_bezier_intersecting_with_closedpath(
#     372     bp, inside, tolerance)
#     373 if len(left) == 2:
#     374     codes_left = [Path.LINETO]
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/bezier.py:334, in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     331 bz = BezierSegment(bezier)
#     332 bezier_point_at_t = bz.point_at_t
# --> 334 t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     335     bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     337 _left, _right = split_de_casteljau(bezier, (t0 + t1) / 2.)
#     338 return _left, _right
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/bezier.py:151, in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     113 def find_bezier_t_intersecting_with_closedpath(
#     114         bezier_point_at_t, inside_closedpath, t0=0., t1=1., tolerance=0.01):
#     115     """
#     116     Find the intersection of the Bezier curve with a closed path.
#     117
#    (...)
#     149         The Bezier path parameters.
#     150     """
# --> 151     start = bezier_point_at_t(t0)
#     152     end = bezier_point_at_t(t1)
#     154     start_inside = inside_closedpath(start)
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/bezier.py:223, in BezierSegment.point_at_t(self, t)
#     219 def point_at_t(self, t):
#     220     """
#     221     Evaluate the curve at a single point, returning a tuple of *d* floats.
#     222     """
# --> 223     return tuple(self(t))
#
# KeyboardInterrupt:

# %%
# Graph Analytics: We use networkX functions to get insight about popular nodes of the graph.


def sort_dict_by_value(dict):
    """Sort a dictionary based on its va;ues

    Args:
        dict (_type_): Python dictionary

    Returns:
        _type_: A new instance of the dictionary sorted by value
    """
    return sorted(dict.items(), key=lambda x: x[1], reverse=True)


topN = 200

# Getting the top-N nodes with highest pagerank value
print(">> Top", topN, "Pagerank articles of wiki graph are:")
pagerankDict = nx.pagerank(G, alpha=0.9)
top_tuples = sort_dict_by_value(pagerankDict)[:topN]
pagerank_nodes = set()
for (key, value) in top_tuples:
    print(key, "->", value)
    pagerank_nodes.add(key)

print()

# Getting the top-N nodes with highest eigenvector centrality value
print(">> Top", topN, "eigenvector centrality articles of wiki graph are:")
bc_dict = nx.eigenvector_centrality(G)
top_tuples = sort_dict_by_value(bc_dict)[:topN]
eigen_nodes = set()
for (key, value) in top_tuples:
    print(key, "->", value)
    eigen_nodes.add(key)

print()

print(">> Top", topN, "Degree Centrality articles of wiki graph are:")
degreeDict = nx.degree_centrality(G)#nx.pagerank(G, alpha=0.9)
top_tuples = sort_dict_by_value(degreeDict)[:topN]
degree_nodes = set()
for (key, value) in top_tuples:
    print(key, "->", value)
    degree_nodes.add(key)
# Out:
# >> Top 200 Pagerank articles of wiki graph are:
# United_States -> 0.00977324494244742
# France -> 0.006823269799314179
# Europe -> 0.006685270249889305
# United_Kingdom -> 0.006516000824162603
# English_language -> 0.005156375084213169
# Germany -> 0.005125973207380523
# World_War_II -> 0.004950326981162153
# Latin -> 0.004682639237183847
# England -> 0.004546831105899607
# India -> 0.004328045220777949
# Japan -> 0.004093543145074442
# Italy -> 0.003961205921913621
# Spain -> 0.003905071683382449
# Time_zone -> 0.003819166904467246
# China -> 0.0038048877032603166
# Russia -> 0.0037391778255280016
# Currency -> 0.0036069326570562195
# Canada -> 0.0035350102647443535
# Africa -> 0.003313619007430789
# Australia -> 0.0032930562114677534
# Christianity -> 0.0032860993924940488
# List_of_countries_by_system_of_government -> 0.0031666761245762137
# London -> 0.003096929229932251
# United_Nations -> 0.0030653331983923606
# Islam -> 0.0029930649026853134
# French_language -> 0.002966328058755238
# North_America -> 0.002761048904051675
# World_War_I -> 0.002702454552912427
# Animal -> 0.0026391343090167254
# Egypt -> 0.002629990680925814
# Portugal -> 0.002585979162642869
# 19th_century -> 0.0025856115310590854
# European_Union -> 0.0025430794464031555
# 20th_century -> 0.002478051370814288
# Earth -> 0.00245780429773906
# Netherlands -> 0.0024530033396289418
# People%27s_Republic_of_China -> 0.0024096400253321958
# Soviet_Union -> 0.0023988843216313028
# Asia -> 0.002363612086521562
# Paris -> 0.0023420028877374215
# Roman_Empire -> 0.0023400654311784065
# Middle_Ages -> 0.0022933244986175823
# Scientific_classification -> 0.002288751874208186
# Atlantic_Ocean -> 0.002216602227326209
# Scotland -> 0.0022042998175853226
# Sweden -> 0.002176695010458199
# Roman_Catholic_Church -> 0.0021644083744811193
# German_language -> 0.002153513155875736
# Jew -> 0.002110052614191757
# Agriculture -> 0.0020926264209132944
# Poland -> 0.0020602557489833567
# Arabic_language -> 0.0020159805434120655
# Spanish_language -> 0.0019721874589805565
# Ireland -> 0.001965682000796274
# Football_%28soccer%29 -> 0.001894887452468118
# Middle_East -> 0.001862022626212281
# Brazil -> 0.001849277066737668
# South_Africa -> 0.0018247095754824955
# South_America -> 0.0018132910888506997
# Greece -> 0.0017869942189031802
# Judaism -> 0.0017857213385411525
# Human -> 0.0017553159471976085
# New_Zealand -> 0.0017506205584342622
# Oxygen -> 0.0017286009285904125
# Turkey -> 0.0017202658983320606
# New_York_City -> 0.0017140388930030283
# Rome -> 0.0017110215769844464
# Petroleum -> 0.001706373501185583
# Denmark -> 0.00169201483647323
# Ancient_Rome -> 0.001678620202463745
# Iran -> 0.0016507242288544134
# Israel -> 0.001642420761670813
# Switzerland -> 0.0016416553753627367
# Belgium -> 0.0016279741440989235
# Philosophy -> 0.001621390763476751
# 18th_century -> 0.0016111062488101075
# Mexico -> 0.0015933745914145892
# Great_Britain -> 0.001590654450919307
# Plant -> 0.0015836939307358072
# Buddhism -> 0.0015786237948246461
# Austria -> 0.0015731871928019903
# California -> 0.0015559243898775569
# Mediterranean_Sea -> 0.0015525185840051592
# Iron -> 0.001550438109446051
# Capital -> 0.001534694182062379
# Democracy -> 0.0015292364295373467
# Ottoman_Empire -> 0.001511814126586127
# Water -> 0.0015050789011879554
# Electron -> 0.0014810442317682792
# Mammal -> 0.0014730242138139005
# Indonesia -> 0.0014610052163671987
# Physics -> 0.0014608980726952077
# Climate -> 0.001451948439879435
# Norway -> 0.0014513204180099711
# Mathematics -> 0.0014351306820418529
# Byzantine_Empire -> 0.0014276741575006658
# Chordate -> 0.0014240682552925858
# Pacific_Ocean -> 0.001408212482383634
# Pakistan -> 0.001402682782113165
# Religion -> 0.001400055491106971
# Ancient_Greece -> 0.0013967585111137103
# Science -> 0.0013918073958144174
# Gold -> 0.0013721307223169422
# Euro -> 0.0013661427879822002
# Ukraine -> 0.0013539839657802804
# Government -> 0.0013448774823364487
# Argentina -> 0.0013362289619313751
# Bird -> 0.0012986640056078412
# Bible -> 0.0012964778062736105
# Cold_War -> 0.0012872545421037042
# Communism -> 0.001272688887570331
# Hydrogen -> 0.0012602190625335306
# Hinduism -> 0.0012550589817649758
# Bacteria -> 0.0012439826038830471
# Hungary -> 0.0012372867504699646
# Aristotle -> 0.0012305455750655215
# Portuguese_language -> 0.0012237805784615758
# 16th_century -> 0.0012173414354832905
# Philippines -> 0.00121693179556486
# Sun -> 0.0012142687593156443
# Carbon_dioxide -> 0.0011991524878083328
# British_Empire -> 0.0011926400246187834
# Color -> 0.0011920321685453393
# United_States_dollar -> 0.0011799065553441122
# Earth%27s_atmosphere -> 0.0011714640997554338
# Volcano -> 0.0011707922590951407
# God -> 0.0011652478000973774
# Iraq -> 0.0011540095514868268
# Romania -> 0.0011480688818058546
# Steel -> 0.0011454262390405048
# Ancient_Egypt -> 0.001144386681829765
# Iceland -> 0.001124464812732694
# Copper -> 0.0011223015700661798
# Evolution -> 0.0011216225623394804
# Wales -> 0.001118716370541135
# Energy -> 0.0011159816499108043
# Fish -> 0.0011115709400099645
# Art -> 0.0011063650966669563
# Renaissance -> 0.0010993311810912462
# Economics -> 0.001095714450727195
# Language -> 0.0010945265742683828
# Syria -> 0.001090946388393899
# Phase_%28matter%29 -> 0.0010897132408431533
# Tourism -> 0.0010883459233738265
# Carolus_Linnaeus -> 0.0010822466080410477
# NATO -> 0.0010719016546381567
# Morocco -> 0.0010693700263112679
# Constitutional_monarchy -> 0.0010683385515977322
# Finland -> 0.0010681114622858529
# Television -> 0.0010665744151836121
# Nazi_Germany -> 0.0010647169997032478
# Biology -> 0.001059316269700333
# Chinese_language -> 0.0010525366738095003
# Napoleon_I_of_France -> 0.0010510281469513487
# 17th_century -> 0.001050037979845181
# Natural_gas -> 0.0010458172486967057
# Republic_of_Ireland -> 0.001042882565134196
# Washington%2C_D.C. -> 0.001042760703947722
# Jesus -> 0.0010333325439961032
# Law -> 0.0010325796987524247
# Thailand -> 0.001030010757863394
# William_Shakespeare -> 0.001029422336604509
# Cuba -> 0.0010284577958176054
# Afghanistan -> 0.001027840123270142
# Internet -> 0.0010247422891106598
# Hebrew_language -> 0.001021065539455977
# Electricity -> 0.00101916046024167
# 15th_century -> 0.0010176591823027217
# Vietnam -> 0.0010169097696502742
# Holy_Roman_Empire -> 0.0010140455059373806
# Industrial_Revolution -> 0.0010047003773208363
# Culture -> 0.0010033745913073575
# Magnetism -> 0.001003213692968629
# Chemical_element -> 0.00100286927765598
# Saudi_Arabia -> 0.0009967359940174572
# South_Korea -> 0.0009966147066078441
# Russian_language -> 0.0009906253517181734
# Coal -> 0.0009874207685396854
# Mesopotamia -> 0.0009865034647793067
# North_Africa -> 0.000985864267215251
# Dutch_language -> 0.0009787047844927877
# Lebanon -> 0.000975939372925942
# DNA -> 0.0009749512519859217
# Malaysia -> 0.0009696329176184897
# Gravitation -> 0.0009660600833451382
# Neutron -> 0.0009634714105187248
# Music -> 0.000947534336057152
# 9th_century -> 0.0009460742098127537
# Socialism -> 0.0009422175136363971
# Indian_Ocean -> 0.000938755757814565
# Moscow -> 0.0009384698506067963
# Carbon -> 0.0009375231244725314
# Country -> 0.0009374461913250782
# Mineral -> 0.0009368348607762121
# Medicine -> 0.000932663398779682
# Capitalism -> 0.0009265299374907948
# French_Revolution -> 0.0009131167961719419
# Moon -> 0.000912860956479092
# Albert_Einstein -> 0.000904588968885187
# Nitrogen -> 0.0008963697830236767
#
# >> Top 200 eigenvector centrality articles of wiki graph are:
# United_States -> 0.20687169802159705
# France -> 0.19193513245340335
# United_Kingdom -> 0.183110754575298
# Europe -> 0.17500107172194396
# Time_zone -> 0.15306381720735113
# Currency -> 0.14920627635092745
# Germany -> 0.14839762429077807
# World_War_II -> 0.14726894566833668
# English_language -> 0.14121692519921317
# List_of_countries_by_system_of_government -> 0.14076791284337115
# Spain -> 0.1337540195288853
# India -> 0.12733776826226942
# United_Nations -> 0.12688358187849053
# Russia -> 0.12533830588902548
# Italy -> 0.11921323222915989
# Japan -> 0.11139643753420304
# Islam -> 0.10945877936407808
# Portugal -> 0.10095938696184224
# European_Union -> 0.10035295525559966
# Christianity -> 0.09728879845009086
# Canada -> 0.09507628090684557
# French_language -> 0.09368160036046724
# China -> 0.09330408130021402
# Africa -> 0.09325887713698985
# Netherlands -> 0.09115251102964646
# People%27s_Republic_of_China -> 0.09105040387360527
# Latin -> 0.09104913513510485
# World_War_I -> 0.08880462461610031
# Egypt -> 0.08540572187705078
# Soviet_Union -> 0.08506694759155219
# Poland -> 0.0842264507358188
# Australia -> 0.07799179662929465
# Asia -> 0.0778883232999226
# England -> 0.07777156980857111
# Turkey -> 0.07255772075527893
# Sweden -> 0.06883102148567977
# Agriculture -> 0.06817460093323482
# Belgium -> 0.0677593157987305
# Greece -> 0.06675189577407666
# Jew -> 0.06504327603524743
# Atlantic_Ocean -> 0.0647456829841285
# Roman_Empire -> 0.06442602506579614
# Judaism -> 0.06417675350544427
# Israel -> 0.06379152550418558
# Denmark -> 0.06335188554676845
# German_language -> 0.06320885579302034
# Iran -> 0.06275443072317037
# Ukraine -> 0.061463941238176674
# Arabic_language -> 0.06096349251542382
# North_America -> 0.060914271358409794
# Pakistan -> 0.060895254180748565
# Ottoman_Empire -> 0.06046144693479885
# Middle_East -> 0.05997758267746676
# Switzerland -> 0.05954285223776155
# London -> 0.059067427670713525
# Spanish_language -> 0.058726536456351626
# Middle_Ages -> 0.05871394596035721
# Romania -> 0.05824837835389749
# South_Africa -> 0.057465454408656434
# Hungary -> 0.05730453247770567
# Morocco -> 0.05725937218964462
# Football_%28soccer%29 -> 0.05707519911092974
# Indonesia -> 0.057074258940063335
# Austria -> 0.05680357788286909
# Brazil -> 0.05631566901805867
# Iraq -> 0.05618997645589574
# Mediterranean_Sea -> 0.05551287294802536
# Petroleum -> 0.05536903797089954
# Lebanon -> 0.05528420068910963
# Norway -> 0.05502514031627578
# Democracy -> 0.05455812330968013
# NATO -> 0.054079927195038284
# Roman_Catholic_Church -> 0.05363833200031785
# Paris -> 0.05310454678089828
# 19th_century -> 0.05118352565744981
# Lithuania -> 0.05074855062591011
# Republic_of_Ireland -> 0.050562274665050276
# Syria -> 0.04911647961729053
# Cold_War -> 0.048979123261714934
# Climate -> 0.048534190344459195
# Bulgaria -> 0.04761666162480588
# Communism -> 0.04753856117875591
# Euro -> 0.0473955494766949
# Tunisia -> 0.04722944450782847
# Buddhism -> 0.04688696228026733
# Algeria -> 0.04667894786485128
# Argentina -> 0.04655385567966205
# 20th_century -> 0.045843609304439356
# Finland -> 0.0458391724103721
# Scotland -> 0.04550334118908582
# Thailand -> 0.04527395517308404
# Afghanistan -> 0.04507838936452126
# Iceland -> 0.0448534846242607
# Albania -> 0.04469453387555917
# Philippines -> 0.044531901211796704
# Saudi_Arabia -> 0.044201010531778134
# Vietnam -> 0.04399945323352094
# Great_Britain -> 0.043986645037353125
# Luxembourg -> 0.043948489041342506
# Malta -> 0.04374716129307024
# Cyprus -> 0.043645922684006654
# Capital -> 0.043487642871394165
# Azerbaijan -> 0.04342958867404056
# Ireland -> 0.043185524957426
# South_America -> 0.043080773032799356
# Byzantine_Empire -> 0.04305605011663604
# Armenia -> 0.04272611743598362
# Slovakia -> 0.042677591788778786
# Malaysia -> 0.04264217738715301
# Kazakhstan -> 0.04247741472053214
# British_Empire -> 0.042423977954568266
# Mexico -> 0.042407279483798785
# Georgia_%28country%29 -> 0.04224468750015338
# Constitutional_monarchy -> 0.04215114936648833
# South_Korea -> 0.042145484029269875
# Czech_Republic -> 0.04191091408967068
# Libya -> 0.041455879883289574
# New_Zealand -> 0.04134121578127113
# Sudan -> 0.04131240615844203
# Serbia -> 0.04105506161443055
# Hinduism -> 0.04095097609772129
# Slovenia -> 0.04079840351643609
# Latvia -> 0.04077388002157387
# Croatia -> 0.04074641748302426
# Estonia -> 0.0403430229487817
# Bosnia_and_Herzegovina -> 0.04011091014846471
# Country -> 0.040055303920317864
# Government -> 0.03969736807583657
# Myanmar -> 0.038676331971320095
# Tourism -> 0.038673066582124896
# Mauritania -> 0.03867187373820386
# Cuba -> 0.03810392988903611
# Ancient_Rome -> 0.037770561100318886
# Nazi_Germany -> 0.03767691260266993
# Pacific_Ocean -> 0.03758087950771733
# North_Africa -> 0.037466811164191774
# Portuguese_language -> 0.03694289277388092
# Montenegro -> 0.03675997864751365
# Rome -> 0.03675349675240851
# Singapore -> 0.03652807556148651
# Senegal -> 0.036377608156960416
# New_York_City -> 0.036235017361394034
# Vatican_City -> 0.03574392835991927
# North_Korea -> 0.035261359178232095
# Parliamentary_system -> 0.03505352863783351
# Cameroon -> 0.034876471038697475
# Indian_Ocean -> 0.03486583120220006
# Nigeria -> 0.03468649618678369
# Natural_gas -> 0.0345101780541092
# 18th_century -> 0.03412371122735564
# Moscow -> 0.0340851800676674
# Russian_language -> 0.03388419057267638
# Monaco -> 0.033806554416526406
# California -> 0.03330298684673351
# Ghana -> 0.03330296752210478
# Bangladesh -> 0.033258914874449576
# Holy_Roman_Empire -> 0.03323325375254672
# Religion -> 0.03306198202525908
# Belarus -> 0.03276375180845882
# C%C3%B4te_d%27Ivoire -> 0.03271458526058732
# Earth -> 0.032665664753140825
# Yemen -> 0.03233312242584112
# 15th_century -> 0.03212987279272709
# Madagascar -> 0.03212023802093066
# Cambodia -> 0.03193701393234985
# Republic_of_China -> 0.03190638615310269
# Andorra -> 0.03188583843951891
# Napoleon_I_of_France -> 0.03186250106051908
# Mozambique -> 0.03171327155233195
# Mali -> 0.03151668903474116
# Guinea -> 0.031273544561974856
# 16th_century -> 0.031238292861915897
# Peru -> 0.031194469970700772
# Somalia -> 0.031152791391056252
# List_of_countries -> 0.031086014079245678
# Ancient_Greece -> 0.030923134807058647
# Monarchy -> 0.030807762532937637
# Hong_Kong -> 0.030758188728252048
# Venezuela -> 0.030274866321613848
# Capitalism -> 0.030129651509929314
# Gabon -> 0.030048165577892222
# Ethiopia -> 0.029981910289682466
# Chinese_language -> 0.029895618916142164
# Togo -> 0.029888202735285398
# Equatorial_Guinea -> 0.02979564230743144
# Moldova -> 0.029644984929240222
# Haiti -> 0.029564462177204043
# Sri_Lanka -> 0.029346798089581228
# Chile -> 0.02931628311485153
# Sierra_Leone -> 0.02917153617450453
# Laos -> 0.02907906200192816
# Liechtenstein -> 0.02897229413470349
# Benin -> 0.028860057171854657
# Jordan -> 0.028809007339633614
# Liberia -> 0.028488985319845908
# Socialism -> 0.02828437516703356
# Turkmenistan -> 0.028283774453863972
# Taiwan -> 0.028280291512609055
# North_Sea -> 0.028214224735969386
# Qatar -> 0.0281385297261463
#
# >> Top 200 Degree Centrality articles of wiki graph are:
# United_States -> 0.4018732302330647
# United_Kingdom -> 0.2483119146155522
# Europe -> 0.23785667610542366
# France -> 0.22740143759529516
# England -> 0.20104552385101285
# Germany -> 0.19864953169244173
# World_War_II -> 0.18950119799607928
# English_language -> 0.15595730777608366
# India -> 0.1507296885210194
# London -> 0.15007623611413637
# Africa -> 0.15007623611413637
# Japan -> 0.14615552167283816
# Australia -> 0.14136353735569593
# Italy -> 0.1383140927902418
# Canada -> 0.13809627532128077
# Spain -> 0.13678937050751472
# Russia -> 0.13613591810063166
# China -> 0.12764103681115227
# Scientific_classification -> 0.11849270311478981
# Animal -> 0.11348290132868656
# Asia -> 0.10760182966673927
# North_America -> 0.1060771073840122
# World_War_I -> 0.1058592899150512
# Latin -> 0.10280984534959704
# Netherlands -> 0.09976040078414289
# List_of_countries_by_system_of_government -> 0.09867131343933784
# 19th_century -> 0.09867131343933784
# Scotland -> 0.0980178610324548
# United_Nations -> 0.09671095621868875
# Egypt -> 0.09409714659115662
# Turkey -> 0.0917011544325855
# Paris -> 0.09148333696362448
# South_Africa -> 0.0897407972119364
# Soviet_Union -> 0.08865170986713135
# Israel -> 0.08821607492920933
# 20th_century -> 0.08690917011544326
# French_language -> 0.08690917011544326
# Christianity -> 0.08538444783271619
# Ireland -> 0.08494881289479417
# Time_zone -> 0.08494881289479417
# Sweden -> 0.08473099542583315
# New_York_City -> 0.08451317795687215
# Earth -> 0.08429536048791113
# New_Zealand -> 0.08429536048791113
# Islam -> 0.0838597255499891
# European_Union -> 0.08298845567414508
# Portugal -> 0.08189936832934001
# Atlantic_Ocean -> 0.08168155086037901
# People%27s_Republic_of_China -> 0.08102809845349597
# Greece -> 0.07841428882596385
# Jew -> 0.07710738401219779
# Argentina -> 0.07667174907427576
# Poland -> 0.07601829666739272
# Chordate -> 0.0753648442605097
# South_America -> 0.07471139185362666
# Mexico -> 0.07427575691570465
# Brazil -> 0.07427575691570465
# Iran -> 0.07209758222609454
# Water -> 0.07013722500544543
# Currency -> 0.06817686778479634
# Middle_Ages -> 0.06708778043999129
# List_of_countries -> 0.06686996297103028
# Binomial_nomenclature -> 0.06686996297103028
# Lebanon -> 0.06665214550206927
# Roman_Catholic_Church -> 0.06599869309518623
# Human -> 0.06578087562622523
# German_language -> 0.06578087562622523
# Agriculture -> 0.06490960575038118
# Switzerland -> 0.06403833587453714
# Bird -> 0.06382051840557613
# Middle_East -> 0.06360270093661512
# Belgium -> 0.06338488346765411
# California -> 0.0631670659986931
# Rome -> 0.06229579612284906
# Armenia -> 0.06207797865388805
# Roman_Empire -> 0.061206708778044
# Denmark -> 0.061206708778044
# Austria -> 0.06098889130908299
# Norway -> 0.06098889130908299
# Spanish_language -> 0.06077107384012198
# Philosophy -> 0.06033543890219996
# Pacific_Ocean -> 0.059246351557394904
# British_Empire -> 0.05902853408843389
# Saudi_Arabia -> 0.05881071661947288
# Ancient_Rome -> 0.05859289915051187
# 18th_century -> 0.05815726421258985
# Gold -> 0.05750381180570682
# Georgia_%28country%29 -> 0.05750381180570682
# Ethiopia -> 0.05728599433674581
# Iron -> 0.05685035939882379
# Mozambique -> 0.05663254192986278
# Indonesia -> 0.05641472446090177
# List_of_sovereign_states -> 0.05641472446090177
# Sun -> 0.055979089522979746
# Madagascar -> 0.055543454585057724
# Sudan -> 0.055543454585057724
# Bulgaria -> 0.055543454585057724
# Plant -> 0.055543454585057724
# Driving_on_the_left_or_right -> 0.055543454585057724
# Arabic_language -> 0.05532563711609671
# Mediterranean_Sea -> 0.0551078196471357
# Ottoman_Empire -> 0.054018732302330646
# Petroleum -> 0.053583097364408624
# Capital -> 0.05336527989544762
# Periodic_table -> 0.05314746242648661
# List_of_circulating_currencies -> 0.05314746242648661
# Uganda -> 0.052494010019603576
# Football_%28soccer%29 -> 0.052494010019603576
# Carolus_Linnaeus -> 0.052494010019603576
# Mammal -> 0.052494010019603576
# Washington%2C_D.C. -> 0.052276192550642565
# List_of_elements_by_name -> 0.052058375081681554
# Kenya -> 0.05184055761272054
# Pakistan -> 0.05140492267479852
# Cuba -> 0.05140492267479852
# Physics -> 0.05118710520583751
# Oxygen -> 0.05118710520583751
# Communism -> 0.0509692877368765
# Elizabeth_II_of_the_United_Kingdom -> 0.050315835329993466
# Ukraine -> 0.049880200392071444
# Finland -> 0.04966238292311043
# Ancient_Greece -> 0.04966238292311043
# Azerbaijan -> 0.04922674798518841
# Wales -> 0.0490089305162274
# United_States_dollar -> 0.048791113047266396
# Somalia -> 0.048791113047266396
# Democratic_Republic_of_the_Congo -> 0.048791113047266396
# Albania -> 0.048791113047266396
# Copper -> 0.048573295578305385
# Philippines -> 0.04813766064038336
# Hungary -> 0.04813766064038336
# Florida -> 0.04813766064038336
# President_of_the_United_States -> 0.04791984317142235
# Syria -> 0.04791984317142235
# Slavery -> 0.04791984317142235
# Croatia -> 0.04770202570246134
# Berlin -> 0.04726639076453932
# Peru -> 0.04726639076453932
# Tanzania -> 0.04726639076453932
# Chad -> 0.04726639076453932
# 16th_century -> 0.04704857329557831
# Slovenia -> 0.04704857329557831
# Great_Britain -> 0.0468307558266173
# Religion -> 0.0468307558266173
# 17th_century -> 0.046612938357656286
# Serbia -> 0.046612938357656286
# Mathematics -> 0.046612938357656286
# BBC -> 0.046395120888695275
# Hydrogen -> 0.04595948595077325
# Tourism -> 0.04574166848181224
# Byzantine_Empire -> 0.04574166848181224
# Iraq -> 0.04574166848181224
# Morocco -> 0.04574166848181224
# Afghanistan -> 0.04552385101285123
# Romania -> 0.04552385101285123
# Yemen -> 0.04530603354389022
# Cold_War -> 0.04465258113700719
# Djibouti -> 0.04465258113700719
# Interpol -> 0.044434763668046176
# Electron -> 0.044216946199085165
# Malaysia -> 0.04399912873012416
# Latin_America -> 0.04378131126116315
# Monarchy -> 0.04356349379220214
# Vietnam -> 0.04356349379220214
# George_W._Bush -> 0.04312785885428012
# Chicago -> 0.04312785885428012
# Democracy -> 0.042910041385319106
# Hong_Kong -> 0.042910041385319106
# Olympic_Games -> 0.042692223916358095
# Volcano -> 0.042692223916358095
# Buddhism -> 0.04225658897843607
# Indian_Ocean -> 0.04225658897843607
# Chile -> 0.04225658897843607
# Russian_language -> 0.04203877150947506
# Los_Angeles%2C_California -> 0.04203877150947506
# Judaism -> 0.04182095404051405
# Rwanda -> 0.04160313657155304
# Ancient_Egypt -> 0.04160313657155304
# Beijing -> 0.04138531910259203
# 21st_century -> 0.04116750163363102
# River -> 0.04116750163363102
# Moscow -> 0.04116750163363102
# Dinosaur -> 0.04094968416467001
# Evolution -> 0.040731866695708996
# Nationalism -> 0.040731866695708996
# Aluminium -> 0.040731866695708996
# Adolf_Hitler -> 0.040731866695708996
# Nazi_Germany -> 0.040731866695708996
# NATO -> 0.040514049226747985
# Renaissance -> 0.040296231757786974
# Tropical_cyclone -> 0.04007841428882596
# Coal -> 0.04007841428882596
# Law -> 0.04007841428882596
# Winston_Churchill -> 0.03986059681986495
# Republic_of_Ireland -> 0.03964277935090394
# Thailand -> 0.03964277935090394
# Moon -> 0.03942496188194294
# Phase_%28matter%29 -> 0.039207144412981926
# American_Civil_War -> 0.038989326944020915
# Television -> 0.038989326944020915

# %%
hubs = degree_nodes.intersection(eigen_nodes).intersection(pagerank_nodes)
print(len(hubs))
hubs
# Out:
# 114
# {'16th_century',
#  '18th_century',
#  '19th_century',
#  '20th_century',
#  'Afghanistan',
#  'Africa',
#  'Agriculture',
#  'Ancient_Greece',
#  'Ancient_Rome',
#  'Arabic_language',
#  'Argentina',
#  'Asia',
#  'Atlantic_Ocean',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'British_Empire',
#  'Buddhism',
#  'Byzantine_Empire',
#  'California',
#  'Canada',
#  'Capital',
#  'China',
#  'Christianity',
#  'Cold_War',
#  'Communism',
#  'Cuba',
#  'Currency',
#  'Democracy',
#  'Denmark',
#  'Earth',
#  'Egypt',
#  'England',
#  'English_language',
#  'Europe',
#  'European_Union',
#  'Finland',
#  'Football_%28soccer%29',
#  'France',
#  'French_language',
#  'German_language',
#  'Germany',
#  'Great_Britain',
#  'Greece',
#  'Hungary',
#  'India',
#  'Indian_Ocean',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Islam',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jew',
#  'Judaism',
#  'Latin',
#  'Lebanon',
#  'List_of_countries_by_system_of_government',
#  'London',
#  'Malaysia',
#  'Mediterranean_Sea',
#  'Mexico',
#  'Middle_Ages',
#  'Middle_East',
#  'Morocco',
#  'Moscow',
#  'NATO',
#  'Nazi_Germany',
#  'Netherlands',
#  'New_York_City',
#  'New_Zealand',
#  'North_America',
#  'Norway',
#  'Ottoman_Empire',
#  'Pacific_Ocean',
#  'Pakistan',
#  'Paris',
#  'People%27s_Republic_of_China',
#  'Petroleum',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Religion',
#  'Republic_of_Ireland',
#  'Roman_Catholic_Church',
#  'Roman_Empire',
#  'Romania',
#  'Rome',
#  'Russia',
#  'Russian_language',
#  'Saudi_Arabia',
#  'Scotland',
#  'South_Africa',
#  'South_America',
#  'Soviet_Union',
#  'Spain',
#  'Spanish_language',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Thailand',
#  'Time_zone',
#  'Tourism',
#  'Turkey',
#  'Ukraine',
#  'United_Kingdom',
#  'United_Nations',
#  'United_States',
#  'Vietnam',
#  'World_War_I',
#  'World_War_II'}

# %%
# Link count visualization

links_counts = wiki_graph["outlinks_count"].values

plt.hist(links_counts, bins=100)
plt.title("Histogram of total number of links per article")
plt.xlabel("Number of outgoing Links")
plt.ylabel("Number of Articles")
plt.show()

# %%
# Categories visualization
groups = categories.groupby("category").count()

labels = list(groups.index)
values = list(groups["article"])
X_axis = np.arange(len(labels))

plt.rcParams["font.size"] = "3"

plt.xticks(rotation=90)
plt.bar(labels, values)
plt.show()

# Highest values of our categories
groups = categories.groupby("category").count()
values = list(groups["article"])
highest_cat = groups.sort_values(ascending=False, by=["article"])

print("Top 5 categories:")
highest_cat.head(5)
# Out:
# Top 5 categories:
#                                               article
# category
# subject.Countries                                 229
# subject.Science.Biology.Birds                     161
# subject.Geography.Geography_of_Great_Britain      124
# subject.Science.Chemistry.Chemical_elements       119
# subject.Science.Biology.Mammals                   114

# %% [markdown]
# ### Path analysis
#
# In this section we show our analysis over the paths of wikispeedia.

# %%
# Initialize some helper functions


def quantize_path(str_path):
    return str_path.split(";")


def get_start_node(list_path):
    return list_path[0]


def get_target_node(list_path):
    return list_path[len(list_path) - 1]


def count_backtracks(list_path):
    return list_path.count("<")

# %%
# Loading the finisged path data and processing with the helper functions

paths_finished = pd.read_csv(
    "data/graph/paths_finished.tsv",
    skiprows=15,
    sep="\t",
    names=[
        "hashedIpAddress",
        "timestamp",
        "durationInSec",
        "path",
        "rating",
        "start",
        "target",
    ],
)

# Not needed columns
# paths_finished["status"] = ["Success" for x in range(len(paths_finished.index))]

# Processing and parsing the paths
paths_finished["path"] = paths_finished["path"].apply(quantize_path)
paths_finished["start"] = paths_finished["path"].apply(get_start_node)
paths_finished["target"] = paths_finished["path"].apply(get_target_node)
paths_finished["backtracks"] = paths_finished["path"].apply(count_backtracks)

# Dropping some columns that we will not use
paths_finished = paths_finished.drop(columns=["hashedIpAddress", "timestamp"])

# Check
paths_finished.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 22
#       3 paths_finished = pd.read_csv(
#       4     "data/graph/paths_finished.tsv",
#       5     skiprows=15,
#    (...)
#      15     ],
#      16 )
#      18 # Not needed columns
#      19 # paths_finished["status"] = ["Success" for x in range(len(paths_finished.index))]
#      20
#      21 # Processing and parsing the paths
# ---> 22 paths_finished["path"] = paths_finished["path"].apply(quantize_path)
#      23 paths_finished["start"] = paths_finished["path"].apply(get_start_node)
#      24 paths_finished["target"] = paths_finished["path"].apply(get_target_node)
#
# NameError: name 'quantize_path' is not defined

# %%
# Loading the unfinished paths, just like the previous one

paths_unfinished = pd.read_csv(
    "data/graph/paths_unfinished.tsv",
    skiprows=19,
    sep="\t",
    names=["hashedIpAddress", "timestamp", "durationInSec", "path", "target", "type"],
)

paths_unfinished = paths_unfinished.drop(columns=["hashedIpAddress", "timestamp"])

paths_unfinished["path"] = paths_unfinished["path"].apply(quantize_path)
paths_unfinished["start"] = paths_unfinished["path"].apply(get_start_node)
paths_unfinished["backtracks"] = paths_unfinished["path"].apply(count_backtracks)

# Dropping the timeouts, as we dont know if this fail is due to user being idle or fail to reach
# the final target article.
paths_unfinished = paths_unfinished[paths_unfinished["type"] != "timeout"]

# Check
paths_unfinished.head(10)
# Out:
#     durationInSec                                               path  \
# 1              49                                         [Paraguay]
# 5             175  [4-2-0, United_States, Agriculture, Sugar, Aus...
# 6              19                                            [Logic]
# 9               8                                          [Niobium]
# 10            334  [Saint_Kitts_and_Nevis, United_Kingdom, World_...
# 12            403  [Symmetry, Science, Age_of_Enlightenment, Dark...
# 13             22                                  [Prostate_cancer]
# 14            115        [Tasmanian_Devil, Dog, Postage_stamp, Wood]
# 17            245  [Tim_Berners-Lee, England, Atlantic_Ocean, Uni...
# 18             13                                   [Snowball_Earth]
#
#                        target     type                  start  backtracks
# 1            Mount_St._Helens  restart               Paraguay           0
# 5                   Cane_Toad  restart                  4-2-0           0
# 6                Moon_landing  restart                  Logic           0
# 9                Beeching_Axe  restart                Niobium           0
# 10               Sandy_Koufax  restart  Saint_Kitts_and_Nevis           0
# 12  Scottish_Episcopal_Church  restart               Symmetry           0
# 13                      Du_Fu  restart        Prostate_cancer           0
# 14                       Love  restart        Tasmanian_Devil           0
# 17              Volcanic_pipe  restart        Tim_Berners-Lee           0
# 18             Medal_of_Honor  restart         Snowball_Earth           0

# %%
# Time duration analysis and plotting
duration_finish = paths_finished["durationInSec"].to_numpy()
duration_unfinish = paths_unfinished["durationInSec"].to_numpy()

duration = [duration_finish, duration_unfinish]

fig = plt.figure(figsize=(7, 7))
plt.rcParams["font.size"] = "12"

plt.boxplot(duration, showfliers=False, labels=["Finished paths", "Unfinished paths"])
plt.title("Time duration per finished or unfinished game")
plt.show()

# %%
# Backtrack analysis and plotting

backtracks_finished = list(paths_finished["backtracks"])
backtracks_unfinished = list(paths_unfinished["backtracks"])


fig, (ax1) = plt.subplots(1, 1)

ax1.set_ylabel("Number of games")
ax1.set_xlabel("Number of Backtracks")
ax1.set_title("Backtracks in games")
ax1.hist(backtracks_finished, bins=30, label="Finished games")
ax1.hist(backtracks_unfinished, bins=30, label="Unfinished games")
ax1.set_xlim(0, 15)
ax1.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Link Position Analysis
#
# In this section we present our preliminary analysis for the link position in the HTML pages.
#
# For each article page, we scrape the html source code to retrieve the links and the paragraph number in which they are placed. Aso a label is stored with the label 'Lead' or 'Body'. The dictionary has the form:
#
# {"page_name" : {"link_page_name_1" : ["paragraph_number_1","lead"] , "link_page_name_2" : "paragraph_number_2","body"}}

# %%
# Importing additional libraries needed for this analysis
import os
from bs4 import BeautifulSoup
import urllib.parse
from tqdm import tqdm

# This path is present locally in our machines, because the size is too big to upload it to the repo.
path = "./data/graph/wpcd"
page_pos_dict = dict()
pars = []

# This routine requires long time to run
for article_name in tqdm(wiki_graph["article"]):
    for root, dirs, files in os.walk(path):
        for name in files:
            if name == "{}.htm".format(article_name):
                try:
                    with open(os.path.join(root, name), encoding="utf-8") as file:
                        soup = BeautifulSoup(file, "lxml")
                    links_dict = dict()
                    par_len = [len(par.getText()) for par in soup.find_all("p")]
                    if 1 in par_len and 0 in par_len:
                        index = min(par_len.index(0), par_len.index(1))
                    elif 1 in par_len:
                        index = par_len.index(1)
                    elif 0 in par_len:
                        index = par_len.index(0)
                    else:
                        index = len(par_len)
                    for i, p in enumerate(soup.find_all("p")):
                        for link in p.find_all("a"):
                            link_title = link.get("title")
                            if (
                                link_title != None
                                and link_title != ""
                                and "jpg" not in link_title
                                and "png" not in link_title
                            ):
                                if (
                                    urllib.parse.quote(link_title.replace(" ", "_"))
                                    not in links_dict.keys()
                                ):
                                    links_dict[
                                        urllib.parse.quote(link_title.replace(" ", "_"))
                                    ] = (i, "lead" if i < index else "body")
                    page_pos_dict[article_name] = links_dict
                except Exception:
                    # A small number of articles throw an exception on parsing, we skip them.
                    pass
                    # print(Exception)
                    # print(
                    #    os.path.join(root, name)
                    # )  # 5 pages cause an exception, because html cannot be decoded
# Out:
# 100%|██████████| 4589/4589 [05:46<00:00, 13.25it/s]

# %%
# Saving our results as json to be able to load them without re-running the cell above
import json

with open("page_pos_dict.json", "w") as outfile:
    json.dump(page_pos_dict, outfile)

# %%
# Uncomment the following cell to load the results from the dictionary.
with open("page_pos_dict.json", "r") as file:
    page_pos_dict = json.load(file)

page_pos_dict
# Out:
# {'%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': {'D%C3%A1l_Riata': [0, 'lead'],
#   'Kingdom': [0, 'lead'],
#   'Scotland': [0, 'lead'],
#   'Ireland': [0, 'lead'],
#   'Columba': [0, 'lead'],
#   'Great_Britain': [0, 'lead'],
#   'Orkney_Islands': [0, 'lead'],
#   'Isle_of_Man': [0, 'lead'],
#   'Bede': [0, 'lead'],
#   'Picts': [7, 'body'],
#   'Wales': [14, 'body']},
#  '%C3%85land': {'Baltic_Sea': [0, 'lead'],
#   'Finland': [0, 'lead'],
#   'Sweden': [1, 'lead'],
#   'League_of_Nations': [4, 'body'],
#   'European_Union': [4, 'body'],
#   'Nationality': [5, 'body'],
#   'Russia': [7, 'body'],
#   'United_Kingdom': [8, 'body'],
#   'Crimean_War': [9, 'body'],
#   '20th_century': [13, 'body'],
#   'World_War_II': [13, 'body'],
#   'Parliamentary_system': [15, 'body'],
#   'Police': [16, 'body'],
#   'Stockholm': [24, 'body'],
#   'Tourism': [30, 'body']},
#  '%C3%89douard_Manet': {'France': [1, 'lead'],
#   'Impressionism': [1, 'lead'],
#   'Paris': [4, 'body'],
#   'Sweden': [4, 'body'],
#   'Germany': [6, 'body'],
#   'Italy': [6, 'body'],
#   'Netherlands': [6, 'body'],
#   'Diego_Vel%C3%A1zquez': [6, 'body'],
#   'Francisco_Goya': [6, 'body'],
#   'Absinthe': [7, 'body'],
#   'Raphael': [14, 'body'],
#   'Renaissance': [15, 'body'],
#   'Photography': [17, 'body'],
#   'Claude_Monet': [23, 'body'],
#   'Beer': [33, 'body'],
#   'Landscape': [44, 'body'],
#   'Washington%2C_D.C.': [48, 'body'],
#   'Edgar_Allan_Poe': [51, 'body'],
#   'United_States_dollar': [59, 'body']},
#  '%C3%89ire': {'Ireland': [0, 'lead'],
#   'English_language': [0, 'lead'],
#   'Republic_of_Ireland': [1, 'lead'],
#   'George_VI_of_the_United_Kingdom': [8, 'body'],
#   'Ottawa': [10, 'body'],
#   'Canada': [10, 'body'],
#   'Northern_Ireland': [10, 'body'],
#   'United_Kingdom': [15, 'body']},
#  '%C3%93engus_I_of_the_Picts': {'D%C3%A1l_Riata': [1, 'lead'],
#   'Scotland': [1, 'lead'],
#   'Ireland': [1, 'lead'],
#   'England': [1, 'lead'],
#   'Vikings': [1, 'lead'],
#   'Mercia': [13, 'body'],
#   'York': [13, 'body'],
#   'Durham': [21, 'body']},
#  '%E2%82%AC2_commemorative_coins': {'History': [0, 'lead'],
#   'Monaco': [3, 'body'],
#   'Vatican_City': [3, 'body'],
#   'Pope_John_Paul_II': [3, 'body'],
#   'Austria': [8, 'body'],
#   'Belgium': [8, 'body'],
#   'Finland': [8, 'body'],
#   'Germany': [8, 'body'],
#   'Greece': [8, 'body'],
#   'Italy': [8, 'body'],
#   'Luxembourg': [8, 'body'],
#   'San_Marino': [8, 'body'],
#   'Spain': [8, 'body'],
#   'France': [8, 'body'],
#   'Ireland': [8, 'body'],
#   'Netherlands': [8, 'body'],
#   'Portugal': [8, 'body'],
#   'Heraldry': [11, 'body'],
#   'Hamburg': [19, 'body'],
#   'Munich': [19, 'body'],
#   'United_States': [20, 'body']},
#  '10th_century': {'Time': [0, 'lead'], 'Dark_Ages': [3, 'body']},
#  '11th_century': {'Time': [0, 'lead'],
#   'Dark_Ages': [2, 'body'],
#   'Crusades': [2, 'body'],
#   'Byzantine_Empire': [4, 'body'],
#   'Norman_conquest_of_England': [5, 'body']},
#  '12th_century': {'Time': [0, 'lead']},
#  '13th_century': {'Time': [0, 'lead']},
#  '14th_century': {'Time': [0, 'lead']},
#  '15th_Marine_Expeditionary_Unit': {'California': [0, 'lead'],
#   'World_War_II': [6, 'body'],
#   'Indian_Ocean': [7, 'body'],
#   'Persian_Gulf': [7, 'body'],
#   'Mount_Pinatubo': [10, 'body'],
#   'Famine': [11, 'body'],
#   'Somalia': [11, 'body'],
#   'Mogadishu': [11, 'body'],
#   'Rwanda': [12, 'body'],
#   'Uganda': [12, 'body'],
#   'Iraq': [13, 'body'],
#   'Kuwait': [13, 'body'],
#   'Kuwait_City': [13, 'body'],
#   'Australia': [15, 'body'],
#   'East_Timor': [15, 'body'],
#   'Pakistan': [18, 'body'],
#   'Afghanistan': [19, 'body'],
#   'United_Kingdom': [21, 'body'],
#   'Royal_Marines': [21, 'body'],
#   '2004_Indian_Ocean_earthquake': [23, 'body'],
#   'Sumatra': [23, 'body'],
#   'Indonesia': [23, 'body'],
#   'Sri_Lanka': [23, 'body']},
#  '15th_century': {'Time': [0, 'lead']},
#  '16_Cygni': {'Triple_star': [2, 'lead'],
#   'Sun': [2, 'lead'],
#   'Red_dwarf': [2, 'lead'],
#   'Extrasolar_planet': [2, 'lead'],
#   'Solar_system': [7, 'body'],
#   'Day': [9, 'body'],
#   '16_Cygni_Bb': [9, 'body'],
#   'Jupiter': [9, 'body']},
#  '16_Cygni_Bb': {'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Star': [0, 'lead'],
#   '16_Cygni': [0, 'lead'],
#   'Triple_star': [0, 'lead'],
#   'Day': [0, 'lead'],
#   'Planet': [2, 'body'],
#   'Jupiter': [2, 'body'],
#   'Solar_system': [4, 'body'],
#   'Binary_star': [4, 'body'],
#   'Season': [8, 'body'],
#   'Earth': [8, 'body'],
#   'Water': [8, 'body']},
#  '16th_century': {'Time': [0, 'lead']},
#  '1755_Lisbon_earthquake': {'Earthquake': [0, 'lead'],
#   'Tsunami': [0, 'lead'],
#   'Lisbon': [0, 'lead'],
#   'Portugal': [0, 'lead'],
#   'Philosophy': [1, 'lead'],
#   'Atlantic_Ocean': [1, 'lead'],
#   'Europe': [4, 'body'],
#   'Finland': [4, 'body'],
#   'North_Africa': [4, 'body'],
#   'Martinique': [4, 'body'],
#   'Barbados': [4, 'body'],
#   'England': [4, 'body'],
#   'Ireland': [4, 'body'],
#   'Morocco': [5, 'body'],
#   'Peter_Paul_Rubens': [5, 'body'],
#   'Vasco_da_Gama': [5, 'body'],
#   'Voltaire': [13, 'body'],
#   'Gottfried_Leibniz': [13, 'body'],
#   'Holocaust': [13, 'body'],
#   'Jean-Jacques_Rousseau': [14, 'body'],
#   'Immanuel_Kant': [15, 'body'],
#   'Rene_Descartes': [16, 'body'],
#   'Geology': [21, 'body']},
#  '17th_century': {'Time': [0, 'lead']},
#  '1896_Summer_Olympics': {'Athens': [0, 'lead'],
#   'Greece': [0, 'lead'],
#   'Olympic_Games': [0, 'lead'],
#   'Roman_Empire': [0, 'lead'],
#   'Christianity': [0, 'lead'],
#   'Paris': [1, 'lead'],
#   'Germany': [2, 'lead'],
#   'Europe': [5, 'body'],
#   'London': [6, 'body'],
#   'Cricket': [7, 'body'],
#   'Football_%28soccer%29': [7, 'body'],
#   'Eastern_Orthodox_Church': [14, 'body'],
#   'Roman_Catholic_Church': [14, 'body'],
#   'Greek_War_of_Independence': [14, 'body'],
#   'Athletics_%28track_and_field%29': [21, 'body'],
#   'France': [24, 'body'],
#   'Austria': [24, 'body'],
#   'Switzerland': [30, 'body'],
#   'United_States': [33, 'body'],
#   'Egypt': [41, 'body']},
#  '18th_century': {'Time': [0, 'lead'],
#   'Louis_XIV_of_France': [1, 'lead'],
#   'French_Revolution': [1, 'lead'],
#   'Glorious_Revolution': [1, 'lead']},
#  '1928_Okeechobee_Hurricane': {'Tropical_cyclone': [0, 'lead'],
#   'Puerto_Rico': [0, 'lead'],
#   'Bahamas': [0, 'lead'],
#   'Florida': [0, 'lead'],
#   'Atlantic_basin': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Guadeloupe': [1, 'lead'],
#   'Africa': [3, 'body'],
#   'United_States_Virgin_Islands': [4, 'body'],
#   'Toronto': [8, 'body'],
#   'Dominica': [11, 'body'],
#   'Martinique': [11, 'body'],
#   'Paris': [11, 'body'],
#   'Montserrat': [11, 'body'],
#   'Latin_America': [15, 'body'],
#   'Galveston_Hurricane_of_1900': [21, 'body'],
#   'Norfolk': [24, 'body']},
#  '1973_oil_crisis': {'Egypt': [0, 'lead'],
#   'Syria': [0, 'lead'],
#   'Yom_Kippur_War': [0, 'lead'],
#   'Petroleum': [0, 'lead'],
#   'Israel': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Arab-Israeli_conflict': [3, 'body'],
#   'World_War_II': [3, 'body'],
#   'Mineral': [3, 'body'],
#   'Middle_East': [4, 'body'],
#   'United_States_dollar': [4, 'body'],
#   'Richard_Nixon': [4, 'body'],
#   'Bretton_Woods_system': [4, 'body'],
#   'Gold': [4, 'body'],
#   'Venezuela': [8, 'body'],
#   'United_Kingdom': [8, 'body'],
#   'Netherlands': [8, 'body'],
#   'Iran': [11, 'body'],
#   'Wheat': [11, 'body'],
#   'Demand': [13, 'body'],
#   'Newspaper': [22, 'body'],
#   'Wood_fuel': [26, 'body'],
#   'North_America': [26, 'body'],
#   'Coal': [26, 'body'],
#   'Australia': [27, 'body'],
#   'Natural_gas': [27, 'body'],
#   'Canada': [29, 'body'],
#   'Soviet_Union': [30, 'body'],
#   'Russia': [30, 'body'],
#   'Electronics': [32, 'body'],
#   'Cold_War': [36, 'body'],
#   'People%27s_Republic_of_China': [36, 'body'],
#   'Latin_America': [36, 'body'],
#   'Chile': [37, 'body'],
#   'United_Nations': [39, 'body'],
#   'Market': [39, 'body'],
#   'Saudi_Arabia': [41, 'body'],
#   'Nuclear_power': [42, 'body'],
#   'Ethanol': [42, 'body'],
#   'Persian_Gulf': [43, 'body'],
#   'Mexico': [43, 'body'],
#   'Nigeria': [43, 'body'],
#   'Algeria': [43, 'body'],
#   'Libya': [43, 'body'],
#   'Kuwait': [46, 'body'],
#   'BBC': [46, 'body']},
#  '1980_eruption_of_Mount_St._Helens': {'Volcano': [0, 'lead'],
#   'U.S._state': [0, 'lead'],
#   'California': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Earthquake': [0, 'lead'],
#   'Magma': [0, 'lead'],
#   'Mount_St._Helens': [0, 'lead'],
#   'Earth%27s_atmosphere': [1, 'lead'],
#   'Snow': [1, 'lead'],
#   'Ice': [1, 'lead'],
#   'Glacier': [1, 'lead'],
#   'Columbia_River': [1, 'lead'],
#   'Animal': [1, 'lead'],
#   'Avalanche': [5, 'body'],
#   'Radio': [11, 'body'],
#   'Wave': [13, 'body'],
#   'Forest': [17, 'body'],
#   'Tree': [17, 'body'],
#   'Water': [18, 'body'],
#   'Sound': [18, 'body'],
#   'Human': [21, 'body'],
#   'Yellowstone_National_Park': [27, 'body'],
#   'Denver%2C_Colorado': [27, 'body'],
#   'Minnesota': [27, 'body'],
#   'Rain': [28, 'body'],
#   'Flood': [30, 'body'],
#   'Ocean': [32, 'body'],
#   'Jimmy_Carter': [35, 'body'],
#   'Moon': [35, 'body'],
#   'Energy': [36, 'body'],
#   'Nuclear_weapon': [36, 'body'],
#   'Wheat': [37, 'body'],
#   'Apple': [37, 'body'],
#   'Potato': [37, 'body'],
#   'Transport': [39, 'body'],
#   'Seattle%2C_Washington': [39, 'body'],
#   'United_States_Congress': [42, 'body'],
#   'Emotion': [43, 'body'],
#   'Tourism': [44, 'body'],
#   'Oregon': [44, 'body'],
#   'Wind': [47, 'body'],
#   'Carbon_dioxide': [49, 'body']},
#  '1997_Pacific_hurricane_season': {'Tropical_cyclone': [0, 'lead'],
#   'Meteorology': [0, 'lead'],
#   'Mexico': [1, 'lead'],
#   'Pacific_Ocean': [3, 'body'],
#   'El_Ni%C3%B1o': [4, 'body'],
#   'Caribbean_Sea': [10, 'body'],
#   'Nicaragua': [11, 'body'],
#   'California': [27, 'body'],
#   'U.S._state': [31, 'body'],
#   'Johnston_Atoll': [36, 'body'],
#   'Wake_Island': [37, 'body'],
#   'United_States': [46, 'body'],
#   'Palmyra_Atoll': [60, 'body'],
#   'Japan': [77, 'body'],
#   'Guam': [77, 'body']},
#  '19th_century': {'World_War_I': [1, 'lead'],
#   'Ottoman_Empire': [2, 'lead'],
#   'Holy_Roman_Empire': [2, 'lead'],
#   'Napoleonic_Wars': [3, 'lead'],
#   'British_Empire': [3, 'lead'],
#   'Slavery': [4, 'lead'],
#   'Germany': [5, 'lead'],
#   'Japan': [5, 'lead'],
#   'United_States': [5, 'lead'],
#   'Qing_Dynasty': [5, 'lead'],
#   'Romanticism': [20, 'body'],
#   'Impressionism': [20, 'body'],
#   'Paris': [20, 'body'],
#   'Ludwig_van_Beethoven': [22, 'body'],
#   'Fr%C3%A9d%C3%A9ric_Chopin': [22, 'body'],
#   'Pyotr_Ilyich_Tchaikovsky': [22, 'body'],
#   'Richard_Wagner': [22, 'body'],
#   'Steam_engine': [24, 'body'],
#   'Samuel_Taylor_Coleridge': [24, 'body'],
#   'England': [24, 'body'],
#   'Italy': [24, 'body'],
#   'Spain': [24, 'body'],
#   'France': [26, 'body'],
#   'Karl_Marx': [26, 'body'],
#   'Leo_Tolstoy': [27, 'body'],
#   'Fyodor_Dostoevsky': [27, 'body'],
#   'Charles_Dickens': [27, 'body'],
#   'Jane_Austen': [27, 'body'],
#   'Edgar_Allan_Poe': [27, 'body'],
#   'Mark_Twain': [27, 'body'],
#   'Victor_Hugo': [27, 'body'],
#   'Charles_Darwin': [29, 'body'],
#   'The_Origin_of_Species': [29, 'body'],
#   'Evolution': [29, 'body'],
#   'Natural_selection': [29, 'body'],
#   'Louis_Pasteur': [29, 'body'],
#   'Bah%C3%A1%27%C3%AD_Faith': [31, 'body']},
#  '1_Ceres': {'Solar_System': [0, 'lead'],
#   'Roman_mythology': [0, 'lead'],
#   'Germany': [2, 'body'],
#   'Sickle_variant_symbol_of_Ceres': [5, 'body'],
#   'Venus': [5, 'body'],
#   'Astronomical_symbol_of_Venus': [5, 'body'],
#   'Old_symbol_of_Ceres': [5, 'body'],
#   'Other_sickle_variant_symbol_of_Ceres': [5, 'body'],
#   'Comet': [7, 'body'],
#   'Milan': [8, 'body'],
#   'Paris': [8, 'body'],
#   'Carl_Friedrich_Gauss': [9, 'body'],
#   'Planet': [11, 'body'],
#   'Mars': [11, 'body'],
#   'Jupiter': [11, 'body'],
#   '3_Juno': [11, 'body'],
#   '4_Vesta': [11, 'body'],
#   'Asteroid': [11, 'body'],
#   'Pluto': [12, 'body'],
#   'Definition_of_a_planet': [12, 'body'],
#   'Eris_%28dwarf_planet%29': [13, 'body'],
#   'Definition_of_planet': [13, 'body'],
#   'Kuiper_belt': [18, 'body'],
#   '90377_Sedna': [18, 'body'],
#   'Moon': [21, 'body'],
#   'Sun': [22, 'body'],
#   'Cornell_University': [23, 'body'],
#   'Fresh_water': [23, 'body'],
#   'Ultraviolet': [24, 'body'],
#   'Hubble_Space_Telescope': [24, 'body'],
#   'Star': [29, 'body'],
#   'Mexico': [29, 'body'],
#   'Florida': [29, 'body']},
#  '1st_century': {},
#  '1st_century_BC': {'Anno_Domini': [1, 'lead']},
#  '2-6-0': {'4-4-0': [3, 'body'],
#   '4-6-0': [3, 'body'],
#   'United_States': [5, 'body'],
#   'England': [7, 'body']},
#  '2-8-0': {'2-6-0': [3, 'body'],
#   'Pennsylvania_Railroad': [4, 'body'],
#   'United_States': [5, 'body'],
#   '4-4-0': [7, 'body'],
#   'World_War_II': [13, 'body']},
#  '2003_Atlantic_hurricane_season': {'Tropical_cyclone': [0, 'lead'],
#   'Atlantic_basin': [0, 'lead'],
#   'Tropical_Storm_Ana_%282003%29': [0, 'lead'],
#   '2005_Atlantic_hurricane_season': [1, 'lead'],
#   'Tropical_Storm_Odette_%282003%29': [1, 'lead'],
#   'Bermuda': [2, 'lead'],
#   'Portugal': [5, 'body'],
#   'Gulf_of_Mexico': [9, 'body'],
#   'Mexico': [12, 'body'],
#   'Bahamas': [33, 'body'],
#   'Canada': [33, 'body'],
#   'Dominican_Republic': [44, 'body'],
#   'Puerto_Rico': [44, 'body'],
#   'Banana': [50, 'body'],
#   'Haiti': [50, 'body'],
#   'Atlantic_Ocean': [52, 'body']},
#  '2004_Atlantic_hurricane_season': {'Tropical_cyclone': [0, 'lead'],
#   'Atlantic_basin': [0, 'lead'],
#   'U.S._state': [1, 'lead'],
#   'Florida': [1, 'lead'],
#   'Hurricane_Charley': [1, 'lead'],
#   'Hurricane_Ivan': [1, 'lead'],
#   'Haiti': [1, 'lead'],
#   'Grenada': [1, 'lead'],
#   'Jamaica': [1, 'lead'],
#   'Cayman_Islands': [1, 'lead'],
#   'Bahamas': [1, 'lead'],
#   'Cuba': [1, 'lead'],
#   'El_Ni%C3%B1o': [7, 'body'],
#   '2005_Atlantic_hurricane_season': [11, 'body'],
#   'Dominican_Republic': [15, 'body'],
#   'Tropical_Storm_Bonnie_%282004%29': [17, 'body'],
#   'Hurricane_Alex_%282004%29': [18, 'body'],
#   'Pacific_Ocean': [18, 'body'],
#   'Hurricane_Katrina': [19, 'body'],
#   'Gulf_of_Mexico': [19, 'body'],
#   'Tropical_storm': [19, 'body'],
#   'Brazil': [20, 'body'],
#   'United_States': [28, 'body'],
#   'Caribbean_Sea': [31, 'body'],
#   'Cape_Verde': [36, 'body'],
#   'Barbados': [39, 'body'],
#   'Venezuela': [39, 'body'],
#   'Bermuda': [43, 'body'],
#   'Turks_and_Caicos_Islands': [43, 'body'],
#   'Richmond%2C_Virginia': [49, 'body'],
#   'Guadeloupe': [66, 'body'],
#   'Puerto_Rico': [66, 'body'],
#   'West_Virginia': [67, 'body'],
#   'Canal': [82, 'body'],
#   'Hurricane_Georges': [104, 'body'],
#   'Hurricane_Mitch': [104, 'body']},
#  '2004_Indian_Ocean_earthquake': {'Earthquake': [0, 'lead'],
#   'Sumatra': [0, 'lead'],
#   'Indonesia': [0, 'lead'],
#   'Tsunami': [0, 'lead'],
#   'Indian_Ocean': [0, 'lead'],
#   'Sri_Lanka': [0, 'lead'],
#   'India': [0, 'lead'],
#   'Thailand': [0, 'lead'],
#   'Myanmar': [0, 'lead'],
#   'Modern_history': [0, 'lead'],
#   'Asia': [0, 'lead'],
#   'Australia': [0, 'lead'],
#   'Canada': [0, 'lead'],
#   'New_Zealand': [0, 'lead'],
#   'United_Kingdom': [0, 'lead'],
#   'Iran': [0, 'lead'],
#   'Africa': [2, 'lead'],
#   'South_Africa': [2, 'lead'],
#   'Bangladesh': [6, 'body'],
#   'Malaysia': [6, 'body'],
#   'Singapore': [6, 'body'],
#   'Maldives': [6, 'body'],
#   'Russia': [8, 'body'],
#   'Peru': [9, 'body'],
#   'Colombia': [9, 'body'],
#   'Venezuela': [9, 'body'],
#   'Bay_of_Bengal': [12, 'body'],
#   'Mexico': [13, 'body'],
#   'Chile': [13, 'body'],
#   'Arctic': [13, 'body'],
#   '2005_Sumatra_earthquake': [15, 'body'],
#   'Lake_Toba': [18, 'body'],
#   'Moon': [21, 'body'],
#   'Royal_Navy': [23, 'body'],
#   'Radar': [24, 'body'],
#   'World_War_II': [29, 'body'],
#   'Kerala': [31, 'body'],
#   'Somalia': [31, 'body'],
#   'Antarctica': [33, 'body'],
#   'Pacific_Ocean': [34, 'body'],
#   'Krakatoa': [37, 'body'],
#   'United_Nations': [38, 'body'],
#   'Atlantic_Ocean': [38, 'body'],
#   'Sweden': [50, 'body'],
#   'Kofi_Annan': [51, 'body'],
#   'Time_zone': [52, 'body'],
#   'Tokyo': [57, 'body'],
#   'South_China_Sea': [58, 'body'],
#   'Italy': [58, 'body'],
#   'Mediterranean_Sea': [58, 'body'],
#   '1755_Lisbon_earthquake': [58, 'body'],
#   'Natural_disaster': [59, 'body'],
#   'Dune': [61, 'body'],
#   'Infrastructure': [63, 'body'],
#   'Cholera': [63, 'body'],
#   'United_States_dollar': [66, 'body'],
#   'Forest': [75, 'body'],
#   'Vegetation': [75, 'body'],
#   'Biodiversity': [75, 'body'],
#   'Seawater': [76, 'body'],
#   'Salt': [76, 'body'],
#   'Agriculture': [76, 'body'],
#   'Great_Barrier_Reef': [76, 'body'],
#   'Islam': [79, 'body']},
#  '2005_Atlantic_hurricane_season': {'United_States_dollar': [0, 'lead'],
#   'Hurricane_Dennis': [0, 'lead'],
#   'Hurricane_Katrina': [0, 'lead'],
#   'U.S._state': [0, 'lead'],
#   'Florida': [0, 'lead'],
#   'Cuba': [0, 'lead'],
#   'Bahamas': [0, 'lead'],
#   'Haiti': [0, 'lead'],
#   'Guatemala': [0, 'lead'],
#   'Tropical_cyclone': [1, 'lead'],
#   '2004_Atlantic_hurricane_season': [5, 'body'],
#   'El_Ni%C3%B1o-Southern_Oscillation': [5, 'body'],
#   'Grenada': [14, 'body'],
#   'United_States': [14, 'body'],
#   'Caribbean_Sea': [15, 'body'],
#   'Tropical_Storm_Franklin_%282005%29': [16, 'body'],
#   'The_Bahamas': [16, 'body'],
#   'Tropical_Storm_Harvey_%282005%29': [19, 'body'],
#   'Bermuda': [19, 'body'],
#   'Atlantic_Ocean': [19, 'body'],
#   'Cape_Verde': [20, 'body'],
#   'Gulf_of_Mexico': [23, 'body'],
#   'Mississippi_River': [23, 'body'],
#   '1928_Okeechobee_Hurricane': [23, 'body'],
#   'Tropical_Storm_Lee_%282005%29': [24, 'body'],
#   'Iceland': [26, 'body'],
#   'Norway': [26, 'body'],
#   'Hurricane_Philippe_%282005%29': [29, 'body'],
#   'Turks_and_Caicos_Islands': [30, 'body'],
#   'Houston%2C_Texas': [30, 'body'],
#   'Hurricane_Vince_%282005%29': [37, 'body'],
#   'Spain': [37, 'body'],
#   'Jamaica': [38, 'body'],
#   'Dominican_Republic': [39, 'body'],
#   'Colombia': [40, 'body'],
#   'Nicaragua': [40, 'body'],
#   'Honduras': [42, 'body'],
#   'Belize': [42, 'body'],
#   'Tropical_Storm_Delta_%282005%29': [43, 'body'],
#   'Hurricane_Epsilon_%282005%29': [44, 'body'],
#   'Tropical_Storm_Zeta_%282005%29': [45, 'body'],
#   'Hurricane_Andrew': [48, 'body'],
#   'Mexico': [49, 'body'],
#   'Europe': [57, 'body'],
#   'Morocco': [57, 'body'],
#   'Refining': [60, 'body'],
#   'Petroleum': [60, 'body'],
#   'Oil_refinery': [61, 'body'],
#   'Citrus': [62, 'body'],
#   'Vegetable': [62, 'body'],
#   'Banana': [62, 'body'],
#   'Coffee': [62, 'body'],
#   'George_W._Bush': [63, 'body'],
#   'Hurricane_Floyd': [81, 'body'],
#   'Hurricane_Lenny': [81, 'body']},
#  '2005_Hertfordshire_Oil_Storage_Terminal_fire': {'M1_motorway': [0, 'lead'],
#   'England': [0, 'lead'],
#   'Europe': [0, 'lead'],
#   'France': [3, 'body'],
#   'Netherlands': [3, 'body'],
#   'Pollution': [8, 'body'],
#   'Spain': [16, 'body'],
#   'Ozone': [17, 'body'],
#   'Library': [21, 'body']},
#  '2005_Kashmir_earthquake': {'Earthquake': [0, 'lead'],
#   'Kashmir': [0, 'lead'],
#   'United_Nations': [2, 'body'],
#   'India': [2, 'body'],
#   'Pakistan': [2, 'body'],
#   '2004_Indian_Ocean_earthquake': [4, 'body'],
#   'Afghanistan': [4, 'body'],
#   'Karachi': [4, 'body'],
#   'Measles': [13, 'body'],
#   'Winter': [13, 'body'],
#   'Snow': [14, 'body']},
#  '2005_Lake_Tanganyika_earthquake': {'Earthquake': [0, 'lead'],
#   'East_Africa': [0, 'lead'],
#   'Great_Rift_Valley': [0, 'lead'],
#   'Lake_Tanganyika': [0, 'lead'],
#   'Democratic_Republic_of_the_Congo': [1, 'lead'],
#   'Second_Congo_War': [1, 'lead'],
#   'African_Great_Lakes': [1, 'lead'],
#   'United_Nations': [2, 'lead'],
#   'Zinc': [2, 'lead'],
#   'Steel': [2, 'lead'],
#   'Burundi': [3, 'lead'],
#   'Tanzania': [3, 'lead'],
#   'Rwanda': [3, 'lead'],
#   'Kenya': [3, 'lead'],
#   'Angola': [4, 'lead']},
#  '2005_Sumatra_earthquake': {'Sumatra': [0, 'lead'],
#   'Indonesia': [0, 'lead'],
#   'Tsunami': [0, 'lead'],
#   '2004_Indian_Ocean_earthquake': [0, 'lead'],
#   'Indian_Ocean': [1, 'lead'],
#   'Jakarta': [1, 'lead'],
#   'Earthquake': [1, 'lead'],
#   'Bangkok': [1, 'lead'],
#   'Thailand': [1, 'lead'],
#   'Kuala_Lumpur': [5, 'body'],
#   'Maldives': [5, 'body'],
#   'India': [5, 'body'],
#   'Sri_Lanka': [5, 'body'],
#   'Malaysia': [7, 'body'],
#   'Mauritius': [9, 'body'],
#   'Madagascar': [9, 'body'],
#   'Seychelles': [9, 'body'],
#   'United_Nations': [12, 'body'],
#   'Australia': [13, 'body'],
#   'Singapore': [13, 'body'],
#   'John_Howard': [13, 'body']},
#  '20th_century': {'War': [2, 'lead'],
#   'World_War_II': [2, 'lead'],
#   '19th_century': [2, 'lead'],
#   'United_States': [5, 'lead']},
#  '21st_century': {'20th_century': [0, 'lead'], 'United_Nations': [11, 'body']},
#  '2nd_century': {'Christian_Era': [0, 'lead']},
#  '3_Juno': {'Asteroid': [0, 'lead'],
#   'Germany': [0, 'lead'],
#   '1_Ceres': [3, 'body'],
#   '4_Vesta': [3, 'body'],
#   'Star': [9, 'body'],
#   'Mars': [10, 'body']},
#  '3rd_century': {'Christian_Era': [0, 'lead']},
#  '4-2-0': {'United_States': [0, 'lead'],
#   'Robert_Stephenson': [3, 'body'],
#   '4-4-0': [10, 'body']},
#  '4-4-0': {'Great_Britain': [0, 'lead'],
#   'North_America': [0, 'lead'],
#   '4-2-0': [2, 'lead'],
#   '2-6-0': [10, 'body'],
#   '2-8-0': [10, 'body'],
#   '4-6-0': [10, 'body'],
#   'Europe': [21, 'body']},
#  '4-6-0': {'United_States': [0, 'lead'],
#   '4-4-0': [7, 'body'],
#   'Pennsylvania_Railroad': [7, 'body']},
#  '47_Ursae_Majoris': {'Star': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Extrasolar_planet': [0, 'lead'],
#   'Solar_system': [2, 'body'],
#   'Iron': [4, 'body'],
#   'Hydrogen': [5, 'body'],
#   'Helium': [5, 'body'],
#   'Gravity': [7, 'body'],
#   '47_Ursae_Majoris_b': [7, 'body'],
#   'Jupiter': [7, 'body'],
#   'Day': [7, 'body'],
#   'Mars': [7, 'body'],
#   '47_Ursae_Majoris_c': [9, 'body'],
#   'Saturn': [10, 'body'],
#   'Water': [11, 'body'],
#   'Planetary_habitability': [13, 'body']},
#  '47_Ursae_Majoris_b': {'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Star': [0, 'lead'],
#   '47_Ursae_Majoris': [0, 'lead'],
#   'Jupiter': [0, 'lead'],
#   'Gravity': [2, 'body'],
#   'Day': [4, 'body'],
#   '47_Ursae_Majoris_c': [4, 'body'],
#   'Solar_system': [4, 'body'],
#   'Gas_giant': [7, 'body'],
#   'Water': [7, 'body'],
#   'Cloud': [7, 'body'],
#   'Ammonia': [7, 'body']},
#  '47_Ursae_Majoris_c': {'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Star': [0, 'lead'],
#   '47_Ursae_Majoris': [0, 'lead'],
#   'Day': [0, 'lead'],
#   'Jupiter': [0, 'lead'],
#   'Gravity': [2, 'body'],
#   '47_Ursae_Majoris_b': [3, 'body'],
#   'Solar_system': [5, 'body'],
#   'Saturn': [5, 'body'],
#   'Gas_giant': [8, 'body']},
#  '4_Vesta': {'Earth': [0, 'lead'],
#   '1_Ceres': [0, 'lead'],
#   'Germany': [2, 'body'],
#   'Carl_Friedrich_Gauss': [2, 'body'],
#   'Roman_mythology': [2, 'body'],
#   'Old_symbol_of_Vesta': [5, 'body'],
#   'Old_planetary_symbol_of_Vesta': [5, 'body'],
#   'Ceres_%28dwarf_planet%29': [6, 'body'],
#   'Solar_System': [6, 'body'],
#   'Planet': [8, 'body'],
#   'Sun': [10, 'body'],
#   'Metal': [13, 'body'],
#   'Iron': [13, 'body'],
#   'Nickel': [13, 'body'],
#   'Crust_%28geology%29': [13, 'body'],
#   'Hubble_Space_Telescope': [18, 'body'],
#   'Solar_system': [24, 'body'],
#   'Mars': [24, 'body'],
#   'Moon': [24, 'body']},
#  '4th_century': {'Time': [0, 'lead'], 'Anno_Domini': [0, 'lead']},
#  '55_Cancri': {'Binary_star': [3, 'lead'],
#   'Star': [3, 'lead'],
#   'Sun': [3, 'lead'],
#   'Red_dwarf': [3, 'lead'],
#   'Earth': [3, 'lead'],
#   'Extrasolar_planet': [4, 'lead'],
#   'Jupiter': [4, 'lead'],
#   'Neptune': [4, 'lead'],
#   'Solar_system': [7, 'body'],
#   'Binoculars': [7, 'body'],
#   'Telescope': [7, 'body'],
#   'Helium': [9, 'body'],
#   'Iron': [9, 'body'],
#   'Upsilon_Andromedae': [12, 'body'],
#   'Day': [12, 'body'],
#   '55_Cancri_b': [12, 'body'],
#   'Gravity': [12, 'body'],
#   'Kuiper_belt': [13, 'body'],
#   '55_Cancri_d': [14, 'body'],
#   '55_Cancri_c': [14, 'body'],
#   '55_Cancri_e': [15, 'body'],
#   'Gas_giant': [15, 'body'],
#   'Hubble_Space_Telescope': [15, 'body']},
#  '55_Cancri_b': {'Star': [0, 'lead'],
#   '55_Cancri': [0, 'lead'],
#   'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Day': [0, 'lead'],
#   'Gravity': [2, 'body'],
#   'Upsilon_Andromedae': [2, 'body'],
#   'Jupiter': [3, 'body'],
#   '55_Cancri_d': [3, 'body'],
#   '55_Cancri_c': [5, 'body'],
#   'Hubble_Space_Telescope': [6, 'body'],
#   'Gas_giant': [8, 'body'],
#   'Cloud': [8, 'body'],
#   'Tide': [9, 'body']},
#  '55_Cancri_c': {'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Star': [0, 'lead'],
#   '55_Cancri': [0, 'lead'],
#   'Day': [0, 'lead'],
#   'Saturn': [0, 'lead'],
#   '55_Cancri_b': [2, 'body'],
#   '55_Cancri_d': [3, 'body'],
#   '55_Cancri_e': [4, 'body'],
#   'Jupiter': [4, 'body'],
#   'Mercury_%28planet%29': [6, 'body'],
#   'Hubble_Space_Telescope': [7, 'body'],
#   'Gas_giant': [9, 'body']},
#  '55_Cancri_d': {'Extrasolar_planet': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   '55_Cancri': [0, 'lead'],
#   'Jupiter': [0, 'lead'],
#   '55_Cancri_b': [2, 'body'],
#   '55_Cancri_c': [3, 'body'],
#   'Solar_system': [5, 'body'],
#   'Pluto': [5, 'body'],
#   'Hubble_Space_Telescope': [6, 'body'],
#   'Gas_giant': [8, 'body'],
#   'Water': [8, 'body'],
#   'Cloud': [8, 'body'],
#   'Heat': [8, 'body'],
#   'Ammonia': [8, 'body']},
#  '55_Cancri_e': {'Extrasolar_planet': [0, 'lead'],
#   'Neptune': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Star': [0, 'lead'],
#   '55_Cancri': [0, 'lead'],
#   'Day': [0, 'lead'],
#   'Earth': [2, 'body'],
#   '55_Cancri_c': [2, 'body'],
#   'Red_dwarf': [3, 'body'],
#   'Jupiter': [7, 'body'],
#   '55_Cancri_b': [7, 'body'],
#   'Tide': [7, 'body'],
#   'Hubble_Space_Telescope': [8, 'body'],
#   '55_Cancri_d': [8, 'body'],
#   'Gravity': [10, 'body'],
#   'Gas_giant': [10, 'body']},
#  '5th_century': {'Christian_Era': [0, 'lead'],
#   'Roman_Empire': [2, 'body'],
#   'Byzantine_Empire': [2, 'body'],
#   'Augustine_of_Hippo': [2, 'body']},
#  '6-2-0': {'4-2-0': [0, 'lead'],
#   'United_States': [3, 'body'],
#   'England': [3, 'body']},
#  '6th_century': {'Christian_Era': [0, 'lead']},
#  '7th_century': {'Christian_Era': [0, 'lead']},
#  '8th_century': {'Christian_Era': [0, 'lead']},
#  '90377_Sedna': {'Solar_system': [0, 'lead'],
#   'California': [2, 'body'],
#   'United_States': [2, 'body'],
#   'Telescope': [2, 'body'],
#   'Chile': [2, 'body'],
#   'Spain': [2, 'body'],
#   'Pluto': [2, 'body'],
#   'Arctic_Ocean': [3, 'body'],
#   'Sun': [5, 'body'],
#   'Hubble_Space_Telescope': [7, 'body'],
#   'Kuiper_belt': [16, 'body'],
#   'Planet': [20, 'body'],
#   'Definition_of_planet': [20, 'body']},
#  '9th_century': {'Time': [0, 'lead'],
#   'Renaissance': [3, 'body'],
#   'Dark_Ages': [3, 'body'],
#   'Western_Roman_Empire': [3, 'body'],
#   'Roman_Catholic_Church': [3, 'body']},
#  'A._E._J._Collins': {'England': [0, 'lead'],
#   'Cricket': [0, 'lead'],
#   'France': [1, 'lead'],
#   'World_War_I': [1, 'lead'],
#   'India': [3, 'body'],
#   'Bristol': [3, 'body'],
#   'Football_%28soccer%29': [4, 'body'],
#   'The_Ashes': [12, 'body'],
#   'Belgium': [17, 'body']},
#  'ABO_blood_group_system': {'Blood_type': [0, 'lead'],
#   'Ape': [0, 'lead'],
#   'Chimpanzee': [0, 'lead'],
#   'Bonobo': [0, 'lead'],
#   'Gorilla': [0, 'lead'],
#   'Bacterium': [10, 'body'],
#   'Plant': [10, 'body'],
#   'European': [17, 'body'],
#   'United_Kingdom': [21, 'body'],
#   'Vikings': [21, 'body'],
#   'Russia': [27, 'body']},
#  'AC_DC': {'Sydney': [0, 'lead'],
#   'Australia': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Glasgow': [4, 'body'],
#   'Scotland': [4, 'body'],
#   'Guitar': [4, 'body'],
#   'New_Zealand': [7, 'body'],
#   'Gorilla': [9, 'body'],
#   'Superman': [9, 'body'],
#   'Television': [14, 'body'],
#   'United_Kingdom': [16, 'body'],
#   'Queen_%28band%29': [16, 'body'],
#   'BBC': [25, 'body'],
#   'England': [25, 'body'],
#   'London': [29, 'body'],
#   'Iron_Maiden': [35, 'body'],
#   'France': [45, 'body'],
#   'Perth%2C_Western_Australia': [46, 'body'],
#   'Europe': [46, 'body'],
#   'Arnold_Schwarzenegger': [47, 'body'],
#   'Hip_hop_music': [49, 'body'],
#   'The_Beatles': [54, 'body'],
#   'Canada': [55, 'body'],
#   'Zeus': [61, 'body'],
#   'Melbourne': [64, 'body'],
#   'Spain': [64, 'body'],
#   'Bluegrass_music': [73, 'body']},
#  'AIDS': {'Human': [1, 'lead'],
#   'HIV': [1, 'lead'],
#   'Virus': [1, 'lead'],
#   'Sub-Saharan_Africa': [2, 'lead'],
#   'Twentieth_century': [2, 'lead'],
#   'World_Health_Organization': [2, 'lead'],
#   'Africa': [2, 'lead'],
#   'Tuberculosis': [5, 'body'],
#   'Genetics': [5, 'body'],
#   'DNA': [13, 'body'],
#   'Bacteria': [15, 'body'],
#   'Fungus': [15, 'body'],
#   'Cancer': [22, 'body'],
#   'Meningitis': [31, 'body'],
#   'Asia': [36, 'body'],
#   'Uganda': [39, 'body'],
#   'Nutrition': [42, 'body'],
#   'C%C3%B4te_d%27Ivoire': [44, 'body'],
#   'Malaria': [45, 'body'],
#   'Zimbabwe': [47, 'body'],
#   'International_Red_Cross_and_Red_Crescent_Movement': [47, 'body'],
#   'South_Africa': [47, 'body'],
#   'HIV-1': [57, 'body'],
#   'Cameroon': [57, 'body'],
#   'Gabon': [57, 'body'],
#   'United_States': [65, 'body'],
#   'Europe': [65, 'body'],
#   'Belgium': [65, 'body'],
#   'Denmark': [65, 'body'],
#   'Finland': [65, 'body'],
#   'France': [65, 'body'],
#   'Germany': [65, 'body'],
#   'Italy': [65, 'body'],
#   'Netherlands': [65, 'body'],
#   'Norway': [65, 'body'],
#   'Sweden': [65, 'body'],
#   'Switzerland': [65, 'body'],
#   'United_Kingdom': [65, 'body']},
#  'AK-47': {'Russian_language': [0, 'lead'],
#   'Russia': [0, 'lead'],
#   'Cold_War': [0, 'lead'],
#   'World_War_II': [0, 'lead'],
#   'Germany': [3, 'body'],
#   'Italy': [4, 'body'],
#   'Chromium': [17, 'body'],
#   'Finland': [31, 'body'],
#   'Israel': [31, 'body'],
#   'India': [31, 'body'],
#   'People%27s_Republic_of_China': [37, 'body'],
#   'Vietnam_War': [37, 'body'],
#   'Canada': [40, 'body'],
#   'United_Kingdom': [42, 'body'],
#   'Norway': [43, 'body'],
#   'Australia': [45, 'body'],
#   'Mexico': [47, 'body'],
#   'Spanish_language': [47, 'body'],
#   'Iraq': [49, 'body'],
#   'Afghanistan': [49, 'body'],
#   'Somalia': [49, 'body'],
#   'Rwanda': [49, 'body'],
#   'Mozambique': [49, 'body'],
#   'Ethiopia': [49, 'body'],
#   'Nicaragua': [51, 'body'],
#   'Burkina_Faso': [52, 'body']},
#  'ALCO_FA': {'Canada': [3, 'body'], 'Argentina': [21, 'body']},
#  'ASCII': {'Computer': [0, 'lead'],
#   'Markup_language': [5, 'body'],
#   'AT%26T': [7, 'body'],
#   'Microsoft_Windows': [20, 'body']},
#  'AT%26T': {'United_States': [0, 'lead'],
#   'United_States_Constitution': [20, 'body']},
#  'ATLAS_experiment': {'Switzerland': [0, 'lead'],
#   'Energy': [0, 'lead'],
#   'Proton': [2, 'lead'],
#   'List_of_particles': [4, 'body'],
#   'Momentum': [5, 'body'],
#   'Photon': [8, 'body'],
#   'String_theory': [11, 'body'],
#   'Hawking_radiation': [12, 'body'],
#   'Electric_charge': [14, 'body'],
#   'Silicon': [18, 'body'],
#   'Speed_of_light': [20, 'body'],
#   'Electron': [20, 'body'],
#   'Magnet': [22, 'body'],
#   'Lead': [23, 'body'],
#   'Argon': [23, 'body'],
#   'Central_processing_unit': [33, 'body'],
#   'Statistics': [34, 'body']},
#  'A_Christmas_Carol': {'Charles_Dickens': [0, 'lead'],
#   'Poverty': [10, 'body'],
#   'Theatre': [16, 'body'],
#   'Film': [16, 'body'],
#   'Radio': [16, 'body'],
#   'Television': [16, 'body'],
#   'United_Kingdom': [17, 'body'],
#   'United_States_of_America': [17, 'body']},
#  'A_Tale_of_a_Tub': {'Literature': [0, 'lead'],
#   'Politics': [0, 'lead'],
#   'Medicine': [0, 'lead'],
#   'Christianity': [2, 'body'],
#   'John_Calvin': [2, 'body'],
#   'Religious_Society_of_Friends': [2, 'body'],
#   'Martin_Luther': [2, 'body'],
#   'Church_of_England': [2, 'body'],
#   'Bible': [2, 'body'],
#   'Thomas_Hobbes': [5, 'body'],
#   'Charles_II_of_England': [27, 'body'],
#   'Glorious_Revolution': [27, 'body'],
#   'Oliver_Cromwell': [27, 'body'],
#   'Great_Britain': [29, 'body'],
#   'Industrial_Revolution': [30, 'body'],
#   'Anne_of_Great_Britain': [31, 'body']},
#  'A_Wrinkle_in_Time': {'Latin': [20, 'body'],
#   'Spanish_language': [20, 'body'],
#   'German_language': [20, 'body'],
#   'Portuguese_language': [20, 'body'],
#   'William_Shakespeare': [20, 'body'],
#   'Bible': [37, 'body'],
#   'Jesus': [38, 'body'],
#   'Gautama_Buddha': [38, 'body'],
#   'Mahatma_Gandhi': [38, 'body'],
#   'Johann_Sebastian_Bach': [38, 'body'],
#   'Albert_Einstein': [38, 'body'],
#   'Euclid': [38, 'body']},
#  'A_cappella': {'Music': [0, 'lead'],
#   'Musical_instrument': [0, 'lead'],
#   'Renaissance_music': [0, 'lead'],
#   'Gregorian_chant': [2, 'body'],
#   'Amish': [4, 'body'],
#   'Eastern_Orthodox_Church': [4, 'body'],
#   'Judaism': [7, 'body'],
#   'Beatles': [17, 'body'],
#   'Hindi': [20, 'body'],
#   'English_language': [20, 'body'],
#   'Rapping': [23, 'body']},
#  'Aachen': {'Dutch_language': [1, 'lead'],
#   'French_language': [1, 'lead'],
#   'Latin': [1, 'lead'],
#   'Germany': [1, 'lead'],
#   'Belgium': [1, 'lead'],
#   'Netherlands': [1, 'lead'],
#   'Cologne': [1, 'lead'],
#   'Holy_Roman_Empire': [4, 'body'],
#   'Charlemagne': [5, 'body'],
#   'Middle_Ages': [7, 'body'],
#   'Flanders': [7, 'body'],
#   'English_language': [8, 'body'],
#   'Napoleon_I_of_France': [8, 'body'],
#   'Iron': [10, 'body'],
#   'Button': [10, 'body'],
#   'Tobacco': [10, 'body'],
#   'World_War_II': [13, 'body'],
#   'Paul_of_Tarsus': [13, 'body'],
#   'Nazi': [13, 'body']},
#  'Aardvark': {'Mammal': [0, 'lead'],
#   'Africa': [0, 'lead'],
#   'Afrikaans': [0, 'lead'],
#   'Dutch_language': [0, 'lead'],
#   'Europe': [0, 'lead'],
#   'Pig': [0, 'lead'],
#   'Anteater': [2, 'body'],
#   'Bandicoot': [2, 'body'],
#   'Kenya': [3, 'body'],
#   'Miocene': [3, 'body'],
#   'Pliocene': [3, 'body'],
#   'Madagascar': [3, 'body'],
#   'Ant': [10, 'body'],
#   'Fruit': [10, 'body'],
#   'Ants': [10, 'body'],
#   'Sub-Saharan_Africa': [16, 'body'],
#   'Humans': [16, 'body']},
#  'Aarhus': {'Denmark': [1, 'lead'],
#   'Copenhagen': [4, 'body'],
#   'World_War_II': [13, 'body'],
#   'Football_%28soccer%29': [18, 'body'],
#   'Engineering': [21, 'body'],
#   'Language': [21, 'body'],
#   'Humanities': [22, 'body'],
#   'Science': [22, 'body'],
#   'Europe': [28, 'body'],
#   'Coal': [28, 'body'],
#   'Iron': [28, 'body'],
#   'Agriculture': [29, 'body'],
#   'Germany': [30, 'body'],
#   'Poland': [30, 'body'],
#   'United_Kingdom': [30, 'body'],
#   'Archaeology': [39, 'body'],
#   'Sweden': [42, 'body'],
#   'Norway': [43, 'body'],
#   'Amsterdam': [43, 'body'],
#   'England': [43, 'body'],
#   'France': [43, 'body'],
#   'Spain': [43, 'body'],
#   'Hamburg': [45, 'body']},
#  'Abac%C3%A1': {'Banana': [0, 'lead'],
#   'Philippines': [0, 'lead'],
#   'Sumatra': [0, 'lead'],
#   'World_War_II': [0, 'lead']},
#  'Abacus': {'China': [0, 'lead'],
#   'Japan': [0, 'lead'],
#   'Africa': [0, 'lead'],
#   'Mesopotamia': [2, 'body'],
#   'Latin': [3, 'body'],
#   'Hebrew_language': [3, 'body'],
#   'Roman_Empire': [7, 'body'],
#   'Arithmetic': [22, 'body'],
#   'Inca': [30, 'body']},
#  'Abadan': {'Iran': [0, 'lead'],
#   'Persian_Gulf': [0, 'lead'],
#   'Ptolemy': [2, 'body'],
#   'Abbasid': [4, 'body'],
#   'Salt': [4, 'body'],
#   '20th_century': [5, 'body'],
#   'Oil_refinery': [5, 'body'],
#   'Petroleum': [5, 'body'],
#   'Tehran': [6, 'body'],
#   'Engineering': [13, 'body'],
#   'Chemistry': [13, 'body']},
#  'Abbadid': {'Islam': [0, 'lead'],
#   'Abbasid': [0, 'lead'],
#   'Baghdad': [0, 'lead'],
#   'Middle_Ages': [4, 'body'],
#   'Renaissance': [4, 'body'],
#   'Poetry': [5, 'body'],
#   'Jew': [9, 'body'],
#   'Africa': [11, 'body']},
#  'Abbas_I_of_Persia': {'Afghanistan': [3, 'body'],
#   'Georgia_%28country%29': [4, 'body'],
#   'Armenia': [4, 'body'],
#   'Caspian_Sea': [5, 'body'],
#   'England': [8, 'body'],
#   'Baghdad': [8, 'body'],
#   'Euphrates': [8, 'body'],
#   'Portugal': [9, 'body'],
#   'Iran': [11, 'body'],
#   'Italy': [11, 'body'],
#   'Spain': [11, 'body'],
#   'Mosque': [13, 'body'],
#   'Tigris': [14, 'body'],
#   'Indus_River': [14, 'body']},
#  'Abbasid': {'Arabic_language': [0, 'lead'],
#   'Baghdad': [0, 'lead'],
#   'Spain': [0, 'lead'],
#   'Muhammad': [0, 'lead'],
#   'Damascus': [0, 'lead'],
#   'Iran': [0, 'lead'],
#   'Maghreb': [0, 'lead'],
#   'Egypt': [0, 'lead'],
#   'Iraq': [0, 'lead'],
#   'Mecca': [9, 'body'],
#   'Byzantine_Empire': [13, 'body'],
#   'Syria': [13, 'body'],
#   'Sultan': [22, 'body'],
#   'Aristotle': [26, 'body'],
#   'Euclid': [26, 'body'],
#   'Ptolemy': [26, 'body']},
#  'Abbey': {'Latin': [0, 'lead'],
#   'Christianity': [0, 'lead'],
#   'Abbot': [0, 'lead'],
#   'Egypt': [4, 'body'],
#   '4th_century': [6, 'body'],
#   'Nile': [6, 'body'],
#   'England': [14, 'body'],
#   'France': [14, 'body'],
#   'Spain': [14, 'body'],
#   'Z%C3%BCrich': [15, 'body'],
#   'Cattle': [15, 'body'],
#   'Paul_of_Tarsus': [16, 'body'],
#   'Westminster_Abbey': [26, 'body'],
#   '10th_century': [31, 'body'],
#   'Flanders': [33, 'body'],
#   'Dorset': [38, 'body'],
#   'Bristol': [56, 'body'],
#   'Syria': [58, 'body']},
#  'Abbey_Theatre': {'Dublin': [0, 'lead'],
#   'Ireland': [0, 'lead'],
#   'Theatre': [0, 'lead'],
#   'Irish_theatre': [1, 'lead'],
#   'North_America': [1, 'lead'],
#   'William_Butler_Yeats': [3, 'body'],
#   'Scotland': [4, 'body'],
#   'Wales': [4, 'body'],
#   'England': [5, 'body'],
#   'London': [5, 'body'],
#   'John_Millington_Synge': [7, 'body'],
#   'Manchester': [8, 'body'],
#   'United_States': [12, 'body'],
#   'Edward_VII_of_the_United_Kingdom': [12, 'body'],
#   'Europe': [16, 'body'],
#   'Samuel_Beckett': [18, 'body']},
#  'Abbot': {'Christianity': [0, 'lead'],
#   'Egypt': [2, 'body'],
#   'Syria': [2, 'body'],
#   'Christian_monasticism': [2, 'body'],
#   'English_language': [4, 'body'],
#   'Rule_of_St_Benedict': [5, 'body'],
#   '5th_century': [6, 'body'],
#   '7th_century': [6, 'body'],
#   'York': [8, 'body'],
#   'Abbey': [10, 'body'],
#   'Rome': [10, 'body'],
#   'Leicester': [15, 'body'],
#   'Henry_VIII_of_England': [15, 'body'],
#   'Charlemagne': [16, 'body'],
#   'Genoa': [16, 'body'],
#   '8th_century': [17, 'body'],
#   '10th_century': [18, 'body'],
#   'French_Revolution': [30, 'body'],
#   'Eastern_Orthodox_Church': [32, 'body'],
#   'Church_of_England': [35, 'body'],
#   'Anglican_Communion': [37, 'body']},
#  'Abel_Tasman': {'Netherlands': [0, 'lead'],
#   'New_Zealand': [1, 'lead'],
#   'Fiji': [1, 'lead'],
#   'Australia': [1, 'lead'],
#   'Jakarta': [3, 'body'],
#   'Taiwan': [5, 'body'],
#   'Japan': [5, 'body'],
#   'Sumatra': [5, 'body'],
#   'Mauritius': [5, 'body'],
#   'South_America': [9, 'body'],
#   'Tonga': [11, 'body'],
#   'James_Cook': [14, 'body'],
#   'Thailand': [16, 'body'],
#   'Manila': [16, 'body']},
#  'Aberdeen': {'Scottish_Gaelic_language': [1, 'lead'],
#   'Scotland': [1, 'lead'],
#   'City_status_in_the_United_Kingdom': [1, 'lead'],
#   'Granite': [1, 'lead'],
#   'North_Sea_oil': [1, 'lead'],
#   'England': [7, 'body'],
#   'Edward_III_of_England': [7, 'body'],
#   'Napoleonic_Wars': [9, 'body'],
#   'Edward_VII_of_the_United_Kingdom': [14, 'body'],
#   'Islam': [20, 'body'],
#   'Buddhism': [20, 'body'],
#   'Hinduism': [20, 'body'],
#   'Bah%C3%A1%27%C3%AD_Faith': [20, 'body'],
#   'Middle_Ages': [21, 'body'],
#   'Scottish_Episcopal_Church': [24, 'body'],
#   'London': [28, 'body'],
#   'North_Sea': [32, 'body'],
#   'Europe': [32, 'body'],
#   'Petroleum': [32, 'body'],
#   'Glasgow': [51, 'body'],
#   'Edinburgh': [51, 'body'],
#   'Dundee': [51, 'body'],
#   'Park': [71, 'body'],
#   'Garden': [71, 'body'],
#   'Great_Britain': [73, 'body'],
#   'Commonwealth_Games': [83, 'body'],
#   'France': [90, 'body'],
#   'Netherlands': [90, 'body'],
#   'Orkney': [93, 'body'],
#   'Shetland': [93, 'body'],
#   'Liberal_Democrats': [100, 'body'],
#   'Parliament_of_the_United_Kingdom': [101, 'body'],
#   'European_Union': [103, 'body'],
#   'European_Parliament': [103, 'body']},
#  'Aberration_of_light': {'Speed_of_light': [0, 'lead'],
#   'Earth': [0, 'lead'],
#   'Sun': [0, 'lead'],
#   'Solar_system': [1, 'lead'],
#   'Planet': [4, 'lead'],
#   'Mercury_%28planet%29': [4, 'lead'],
#   'Neptune': [4, 'lead'],
#   'Car': [13, 'body'],
#   'Galileo_Galilei': [34, 'body'],
#   'Tycho_Brahe': [34, 'body'],
#   'Heliocentrism': [34, 'body'],
#   'Johannes_Kepler': [34, 'body'],
#   'Isaac_Newton': [34, 'body'],
#   'John_Flamsteed': [37, 'body'],
#   'London': [37, 'body'],
#   'Earth%27s_atmosphere': [44, 'body']},
#  'Aberystwyth': {'English_language': [0, 'lead'],
#   'Wales': [0, 'lead'],
#   'River': [3, 'body'],
#   'Edward_I_of_England': [18, 'body'],
#   'Henry_V_of_England': [18, 'body'],
#   'Henry_VIII_of_England': [18, 'body'],
#   'Elizabeth_I_of_England': [18, 'body'],
#   'Birmingham': [33, 'body'],
#   'Cardiff': [34, 'body']},
#  'Abhidhamma_Pitaka': {'Pali_Canon': [0, 'lead'],
#   'Buddhism': [0, 'lead'],
#   'Buddha': [4, 'body'],
#   'University_of_Bristol': [4, 'body'],
#   'Sanskrit': [4, 'body']},
#  'Abidjan': {'Capital': [0, 'lead'],
#   'C%C3%B4te_d%27Ivoire': [0, 'lead'],
#   'Yamoussoukro': [0, 'lead'],
#   'Bridge': [0, 'lead'],
#   'Park': [0, 'lead'],
#   'University': [0, 'lead'],
#   'Burkina_Faso': [0, 'lead'],
#   'France': [16, 'body'],
#   'Rainforest': [19, 'body'],
#   'Automobile': [21, 'body'],
#   'Oil_refinery': [21, 'body'],
#   'Train': [23, 'body'],
#   'Ouagadougou': [23, 'body'],
#   'Atlantic_Ocean': [25, 'body'],
#   'Africa': [25, 'body'],
#   'Accra': [25, 'body'],
#   'Dakar': [25, 'body'],
#   'Mali': [25, 'body'],
#   'Niger': [25, 'body'],
#   'Liberia': [43, 'body']},
#  'Abkhazia': {'Russian_language': [0, 'lead'],
#   'Black_Sea': [0, 'lead'],
#   'Georgia_%28country%29': [0, 'lead'],
#   'Country': [0, 'lead'],
#   'United_Nations': [1, 'lead'],
#   'NATO': [3, 'body'],
#   'International_law': [3, 'body'],
#   'Landscape': [9, 'body'],
#   'Tea': [9, 'body'],
#   'Tobacco': [9, 'body'],
#   'Wine': [9, 'body'],
#   'Fruit': [9, 'body'],
#   'River': [10, 'body'],
#   'Roman_Empire': [22, 'body'],
#   'Byzantine_Empire': [22, 'body'],
#   'Christianity': [22, 'body'],
#   'Ottoman_Empire': [23, 'body'],
#   'Islam': [23, 'body'],
#   'Russian_Revolution_of_1917': [26, 'body'],
#   'Soviet_Union': [26, 'body'],
#   'Budapest': [35, 'body'],
#   'Lisbon': [35, 'body'],
#   'Istanbul': [35, 'body'],
#   'Russia': [36, 'body'],
#   'European_Union': [46, 'body']},
#  'Able_Archer_83': {'NATO': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Soviet_Union': [0, 'lead'],
#   'Poland': [0, 'lead'],
#   'President_of_the_United_States': [4, 'body'],
#   'Ronald_Reagan': [4, 'body'],
#   'Greenland': [6, 'body'],
#   'Iceland': [6, 'body'],
#   'United_Kingdom': [6, 'body'],
#   'Black_Sea': [6, 'body'],
#   'Margaret_Thatcher': [15, 'body'],
#   'Invasion_of_Grenada': [16, 'body'],
#   'Elizabeth_II_of_the_United_Kingdom': [16, 'body'],
#   'Mikhail_Gorbachev': [35, 'body']},
#  'Abraham_Goldfaden': {'Russia': [0, 'lead'],
#   'Jew': [0, 'lead'],
#   'Romania': [0, 'lead'],
#   'Hebrew_language': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'German_language': [3, 'body'],
#   'Russian_language': [3, 'body'],
#   'Zionism': [4, 'body'],
#   'Ukraine': [4, 'body'],
#   'Piano': [4, 'body'],
#   'Munich': [6, 'body'],
#   'William_Shakespeare': [11, 'body'],
#   'Bucharest': [17, 'body'],
#   'Moscow': [34, 'body'],
#   'Saint_Petersburg': [34, 'body'],
#   'France': [35, 'body'],
#   'England': [37, 'body'],
#   'New_York_City': [37, 'body'],
#   'Warsaw': [40, 'body'],
#   'Paris': [40, 'body'],
#   'Socialism': [48, 'body'],
#   'Asthma': [50, 'body'],
#   'George_Eliot': [53, 'body'],
#   'Jerusalem': [56, 'body']},
#  'Abraham_Lincoln': {'President_of_the_United_States': [0, 'lead'],
#   'American_Civil_War': [0, 'lead'],
#   'Gettysburg_Address': [0, 'lead'],
#   'United_States_Constitution': [1, 'lead'],
#   'Mississippi_River': [8, 'body'],
#   'Bible': [10, 'body'],
#   'William_Shakespeare': [10, 'body'],
#   'United_States_House_of_Representatives': [21, 'body'],
#   'James_Knox_Polk': [21, 'body'],
#   'Zachary_Taylor': [21, 'body'],
#   'James_Buchanan': [32, 'body'],
#   'Frederick_Douglass': [55, 'body'],
#   'Minnesota': [58, 'body'],
#   'Battle_of_Gettysburg': [60, 'body'],
#   'Ulysses_S._Grant': [60, 'body'],
#   'Andrew_Johnson': [60, 'body'],
#   'Richmond%2C_Virginia': [68, 'body'],
#   'William_Tecumseh_Sherman': [72, 'body'],
#   'Charles_Sumner': [81, 'body'],
#   'Supreme_Court_of_the_United_States': [96, 'body'],
#   'First_Transcontinental_Railroad': [99, 'body'],
#   'Washington%2C_D.C.': [103, 'body'],
#   'U.S._state': [104, 'body'],
#   'Charles_Darwin': [105, 'body'],
#   'Mexico': [107, 'body'],
#   'Lyndon_B._Johnson': [107, 'body'],
#   'Tijuana': [107, 'body'],
#   'United_Kingdom': [107, 'body'],
#   'London': [107, 'body'],
#   'Manchester': [107, 'body'],
#   'Edinburgh': [107, 'body'],
#   'Aircraft_carrier': [108, 'body'],
#   'Ronald_Reagan': [109, 'body']},
#  'Absinthe': {'Ethanol': [0, 'lead'],
#   'Sugar': [0, 'lead'],
#   'Distilled_beverage': [0, 'lead'],
#   'Switzerland': [2, 'lead'],
#   'France': [2, 'lead'],
#   'Paris': [2, 'lead'],
#   'United_States': [2, 'lead'],
#   'European_Union': [2, 'lead'],
#   'Latin': [4, 'body'],
#   'Fennel': [7, 'body'],
#   'Lemon_balm': [7, 'body'],
#   'Star_anise': [7, 'body'],
#   'Angelica': [7, 'body'],
#   'Coriander': [7, 'body'],
#   'Nutmeg': [7, 'body'],
#   'Copper': [11, 'body'],
#   'Zinc': [11, 'body'],
#   'Antimony': [11, 'body'],
#   'Czech_Republic': [22, 'body'],
#   'Prague': [23, 'body'],
#   'Belgium': [35, 'body'],
#   'Brazil': [35, 'body'],
#   'Australia': [35, 'body'],
#   'Spain': [35, 'body'],
#   'United_Kingdom': [37, 'body'],
#   'Portugal': [38, 'body'],
#   'Mexico': [38, 'body'],
#   'Netherlands': [41, 'body'],
#   'Amsterdam': [41, 'body'],
#   'Essential_oil': [53, 'body'],
#   'Common_sage': [53, 'body'],
#   'Vincent_van_Gogh': [59, 'body'],
#   '%C3%89douard_Manet': [59, 'body'],
#   'Pablo_Picasso': [59, 'body'],
#   'Ernest_Hemingway': [59, 'body'],
#   'Canada': [67, 'body'],
#   'Vanuatu': [79, 'body']},
#  'Absolute_zero': {'Quantum_mechanics': [1, 'lead'],
#   'Thermodynamic_temperature': [2, 'lead'],
#   'Galileo_Galilei': [5, 'body'],
#   'Robert_Boyle': [5, 'body'],
#   'Antoine_Lavoisier': [9, 'body'],
#   'William_Thomson%2C_1st_Baron_Kelvin': [11, 'body'],
#   'Thermodynamics': [13, 'body'],
#   'Crystal': [16, 'body'],
#   'Max_Planck': [16, 'body'],
#   'Entropy': [16, 'body'],
#   'Symmetry': [20, 'body'],
#   'Diamond': [20, 'body'],
#   'Carbon': [20, 'body'],
#   'Albert_Einstein': [22, 'body'],
#   'Empiricism': [25, 'body']},
#  'Abstract_art': {'Art': [0, 'lead'],
#   '20th_century': [0, 'lead'],
#   'Cubism': [0, 'lead'],
#   'Calligraphy': [2, 'body'],
#   'Fine_art': [2, 'body'],
#   'Constructivism_%28art%29': [3, 'body']},
#  'Abu_Dhabi': {'Arabic_language': [2, 'lead'],
#   'Gazelle': [2, 'lead'],
#   'Emirate': [2, 'lead'],
#   'United_Arab_Emirates': [2, 'lead'],
#   'Persian_Gulf': [2, 'lead'],
#   '18th_century': [4, 'body'],
#   'Dubai': [4, 'body'],
#   '19th_century': [4, 'body'],
#   '20th_century': [5, 'body'],
#   'Camel': [5, 'body'],
#   'Pearl': [5, 'body'],
#   'Arecaceae': [5, 'body'],
#   'Petroleum': [6, 'body'],
#   'United_Kingdom': [6, 'body'],
#   'Saudi_Arabia': [10, 'body'],
#   'Bangladesh': [13, 'body'],
#   'India': [13, 'body'],
#   'Pakistan': [13, 'body'],
#   'Egypt': [13, 'body'],
#   'Philippines': [13, 'body'],
#   'English_language': [13, 'body'],
#   'Hindi': [13, 'body']},
#  'Abuja': {'Nigeria': [0, 'lead'],
#   'Lagos': [0, 'lead'],
#   'Brazil': [2, 'body'],
#   'Bras%C3%ADlia': [2, 'body']},
#  'Acceleration': {'Physics': [0, 'lead'],
#   'Time': [0, 'lead'],
#   'Earth': [11, 'body'],
#   'Sea': [11, 'body'],
#   'Special_relativity': [16, 'body'],
#   'Albert_Einstein': [16, 'body'],
#   'Light': [16, 'body']},
#  'Accountancy': {'Europe': [6, 'lead'],
#   'Ancient_Greece': [6, 'lead'],
#   'Economics': [7, 'lead'],
#   'Human': [9, 'body'],
#   'Agriculture': [9, 'body'],
#   'Civilization': [9, 'body'],
#   'Mesopotamia': [9, 'body'],
#   'Persian_Empire': [10, 'body'],
#   'Islam': [10, 'body'],
#   'Ottoman_Empire': [10, 'body'],
#   'Croatia': [12, 'body'],
#   'Italy': [12, 'body'],
#   'English_language': [14, 'body'],
#   'London': [14, 'body'],
#   'Capitalism': [27, 'body']},
#  'Accra': {'Ghana': [0, 'lead'],
#   'Clothing': [0, 'lead'],
#   'Portugal': [2, 'body'],
#   'Sweden': [2, 'body'],
#   'Netherlands': [2, 'body'],
#   'France': [2, 'body'],
#   'Denmark': [2, 'body'],
#   'Great_Britain': [3, 'body'],
#   'Earthquake': [4, 'body'],
#   'Africa': [6, 'body'],
#   '17th_century': [8, 'body'],
#   'Beach': [8, 'body']},
#  'Acetic_acid': {'Water': [1, 'body'],
#   'Crystal': [1, 'body'],
#   'Corrosion': [1, 'body'],
#   'Formic_acid': [2, 'body'],
#   'Latin': [5, 'body'],
#   'German_language': [6, 'body'],
#   'Chemical_element': [7, 'body'],
#   'Actinium': [7, 'body'],
#   'Proton': [8, 'body'],
#   'Salt': [8, 'body'],
#   'Beer': [10, 'body'],
#   'Wine': [10, 'body'],
#   'Greece': [11, 'body'],
#   'Pigment': [11, 'body'],
#   'Copper': [11, 'body'],
#   'Rome': [11, 'body'],
#   'Renaissance': [12, 'body'],
#   'Germany': [12, 'body'],
#   'Sulfuric_acid': [14, 'body'],
#   'Deprotonation_equilibrium_of_acetic_acid_in_water': [17, 'body'],
#   'Ethanol': [19, 'body'],
#   'Sugar': [19, 'body'],
#   'Sulfur': [19, 'body'],
#   'Iodine': [19, 'body'],
#   'Metal': [20, 'body'],
#   'Iron': [20, 'body'],
#   'Magnesium': [20, 'body'],
#   'Zinc': [20, 'body'],
#   'Hydrogen': [20, 'body'],
#   'Aluminium': [20, 'body'],
#   'Carbon_dioxide': [21, 'body'],
#   'Iron%28III%29_chloride': [22, 'body'],
#   'Bacterium': [25, 'body'],
#   'Food': [25, 'body'],
#   'Soil': [25, 'body'],
#   'United_States': [28, 'body'],
#   'Europe': [28, 'body'],
#   'Japan': [28, 'body'],
#   'BP': [28, 'body'],
#   'Cobalt': [32, 'body'],
#   'Rhodium': [32, 'body'],
#   'Ruthenium': [32, 'body'],
#   'Iridium': [32, 'body'],
#   'Manganese': [35, 'body'],
#   'Chromium': [35, 'body'],
#   'Oxygen': [37, 'body'],
#   'Earth%27s_atmosphere': [37, 'body'],
#   'Cider': [41, 'body'],
#   'Cereal': [41, 'body'],
#   'Rice': [41, 'body'],
#   'Potato': [41, 'body'],
#   'Yeast': [43, 'body'],
#   'Palladium': [52, 'body'],
#   'Condensation_of_acetic_acid_to_acetic_anhydride': [56, 'body'],
#   'Textile': [57, 'body'],
# ...
#   'Lake_Powell': [4, 'body'],
#   'Grand_Canyon': [5, 'body'],
#   'Hoover_Dam': [6, 'body'],
#   'Lake_Mead': [6, 'body'],
#   'California': [6, 'body'],
#   '20th_century': [8, 'body'],
#   'Uranium': [21, 'body'],
#   'Mining': [21, 'body']},
#  'Colossus_of_Rhodes': {'Greek_mythology': [0, 'lead'],
#   'Greece': [0, 'lead'],
#   'New_York_City': [0, 'lead'],
#   'Alexander_the_Great': [2, 'body'],
#   'Egypt': [2, 'body'],
#   'Zeus': [3, 'body'],
#   'Earthquake': [8, 'body']},
#  'Columba': {'Dove': [1, 'lead'],
#   'Christianity': [1, 'lead'],
#   'Scotland': [1, 'lead'],
#   'Dark_Ages': [1, 'lead'],
#   'Picts': [5, 'body'],
#   'Hebrides': [5, 'body'],
#   '%C3%81ed%C3%A1n_mac_Gabr%C3%A1in': [10, 'body'],
#   'D%C3%A1l_Riata': [10, 'body'],
#   'King_Arthur': [10, 'body']},
#  'Columbia_River': {'River': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Pacific_Ocean': [0, 'lead'],
#   'Mississippi_River': [0, 'lead'],
#   'North_America': [0, 'lead'],
#   'Oregon': [3, 'body'],
#   'Ice_age': [12, 'body'],
#   'Russia': [14, 'body'],
#   'Spain': [14, 'body'],
#   'Missouri_River': [17, 'body'],
#   'London': [18, 'body'],
#   'California': [18, 'body'],
#   'Irrigation': [23, 'body'],
#   'Potato': [23, 'body'],
#   'Wheat': [23, 'body'],
#   'Maize': [23, 'body'],
#   'Barley': [23, 'body'],
#   'Bean': [23, 'body'],
#   'Sugar_beet': [23, 'body'],
#   'Plutonium': [26, 'body']},
#  'Columbine_High_School_massacre': {'Denver%2C_Colorado': [0, 'lead'],
#   'United_States': [0, 'lead'],
#   'Bath_School_disaster': [0, 'lead'],
#   'Film': [1, 'lead'],
#   'Doom': [3, 'body'],
#   'Mexico': [12, 'body'],
#   'New_York_City': [12, 'body'],
#   'Internet': [16, 'body'],
#   'Soccer': [28, 'body'],
#   'Carbon_dioxide': [37, 'body'],
#   'Mass_media': [55, 'body'],
#   'Adolf_Hitler': [56, 'body'],
#   'Music': [57, 'body'],
#   'Federal_Bureau_of_Investigation': [61, 'body']},
#  'Columbus%2C_Ohio': {'Capital': [1, 'lead'],
#   'U.S._state': [1, 'lead'],
#   'United_States': [2, 'lead'],
#   'Cleveland%2C_Ohio': [2, 'lead'],
#   'Benjamin_Franklin': [5, 'body'],
#   'Christopher_Columbus': [7, 'body'],
#   'Baltimore%2C_Maryland': [8, 'body'],
#   'Ireland': [8, 'body'],
#   'Germany': [8, 'body'],
#   'American_Civil_War': [10, 'body'],
#   'Manufacturing': [11, 'body'],
#   'World_War_I': [14, 'body'],
#   'World_War_II': [15, 'body'],
#   'Vietnam': [17, 'body'],
#   'Russia': [17, 'body'],
#   'Somalia': [17, 'body'],
#   'Mexico': [17, 'body'],
#   'Cleveland': [19, 'body'],
#   'Glacier': [20, 'body'],
#   'Drought': [22, 'body'],
#   'Chicago': [31, 'body'],
#   'Microsoft': [51, 'body'],
#   'Federal_Bureau_of_Investigation': [63, 'body'],
#   'Deconstructivism': [88, 'body'],
#   'American_football': [90, 'body'],
#   'Ann_Arbor%2C_Michigan': [90, 'body'],
#   'Ice_hockey': [91, 'body'],
#   'Football_%28soccer%29': [91, 'body'],
#   'National_Hockey_League': [91, 'body'],
#   'Auto_racing': [93, 'body'],
#   'William_Shakespeare': [96, 'body'],
#   'Genoa': [104, 'body'],
#   'Italy': [104, 'body']},
#  'Comet': {'Sun': [0, 'lead'],
#   'Water': [1, 'lead'],
#   'Gas': [1, 'lead'],
#   'Phase_%28matter%29': [1, 'lead'],
#   'Asteroid': [1, 'lead'],
#   'English_language': [2, 'lead'],
#   'Latin': [2, 'lead'],
#   'Aristotle': [2, 'lead'],
#   'Earth': [5, 'body'],
#   'Telescope': [5, 'body'],
#   'England': [5, 'body'],
#   'Comet_Halley': [6, 'body'],
#   'Petroleum': [6, 'body'],
#   'Kuiper_belt': [11, 'body'],
#   'Star': [11, 'body'],
#   'Milky_Way': [11, 'body'],
#   'Galaxy': [11, 'body'],
#   'Comet_Hale-Bopp': [18, 'body'],
#   'Meteorology': [23, 'body'],
#   'Planet': [23, 'body'],
#   'Earth%27s_atmosphere': [23, 'body'],
#   'Meteor': [23, 'body'],
#   'Wind': [24, 'body'],
#   'Denmark': [25, 'body'],
#   'Tycho_Brahe': [25, 'body'],
#   'Johannes_Kepler': [27, 'body'],
#   'Galileo_Galilei': [27, 'body'],
#   'Isaac_Newton': [29, 'body'],
#   'Philosophiae_Naturalis_Principia_Mathematica': [29, 'body'],
#   'Gravity': [29, 'body'],
#   'Edmond_Halley': [30, 'body'],
#   'France': [30, 'body'],
#   'Germany': [31, 'body'],
#   'Immanuel_Kant': [35, 'body'],
#   'Italy': [36, 'body'],
#   'European_Space_Agency': [37, 'body'],
#   'Soviet_Union': [37, 'body'],
#   'Comet_Hyakutake': [48, 'body'],
#   'Mercury_%28planet%29': [50, 'body'],
#   'Comet_Shoemaker-Levy_9': [53, 'body']},
#  'Comet_Hale-Bopp': {'Comet': [0, 'lead'],
#   'Sun': [1, 'lead'],
#   'Great_comet': [1, 'lead'],
#   'Extraterrestrial_life': [2, 'lead'],
#   'United_States': [4, 'body'],
#   'Globular_cluster': [4, 'body'],
#   'Telescope': [5, 'body'],
#   'Galaxy': [5, 'body'],
#   'Comet_Halley': [7, 'body'],
#   'Internet': [11, 'body'],
#   'Solar_eclipse': [12, 'body'],
#   'Mongolia': [12, 'body'],
#   'Sirius': [13, 'body'],
#   'Comet_Hyakutake': [14, 'body'],
#   'Moon': [14, 'body'],
#   'Gravity': [20, 'body'],
#   'Astronomy': [22, 'body'],
#   'Sodium': [24, 'body'],
#   'Electric_charge': [24, 'body'],
#   'Ultraviolet': [25, 'body'],
#   'Ocean': [28, 'body'],
#   'Hydrogen': [29, 'body'],
#   'Hubble_Space_Telescope': [36, 'body'],
#   'Planet': [36, 'body'],
#   'Houston%2C_Texas': [40, 'body'],
#   'Star': [40, 'body']},
#  'Comet_Halley': {'Edmond_Halley': [0, 'lead'],
#   'Comet': [0, 'lead'],
#   '17th_century': [0, 'lead'],
#   'Solar_System': [0, 'lead'],
#   'Johannes_Kepler': [3, 'body'],
#   'Prague': [3, 'body'],
#   'France': [3, 'body'],
#   'Mark_Twain': [10, 'body'],
#   'European_Space_Agency': [16, 'body'],
#   'Soviet_Union': [16, 'body'],
#   'Japan': [16, 'body'],
#   'Space_Shuttle_Challenger_disaster': [19, 'body'],
#   'Mir': [20, 'body'],
#   'Meteor': [25, 'body']},
#  'Comet_Hyakutake': {'Comet': [0, 'lead'],
#   'Earth': [0, 'lead'],
#   'Comet_Hale-Bopp': [0, 'lead'],
#   'Solar_system': [0, 'lead'],
#   'Atom': [1, 'lead'],
#   'Gravity': [2, 'lead'],
#   'Japan': [4, 'body'],
#   'Binoculars': [4, 'body'],
#   'Sun': [6, 'body'],
#   'Great_comet': [8, 'body'],
#   'Star': [13, 'body'],
#   'Full_moon': [13, 'body'],
#   'Carbon': [13, 'body'],
#   'Mercury_%28planet%29': [16, 'body'],
#   'Solar_System': [18, 'body'],
#   'Proton': [21, 'body'],
#   'Water': [27, 'body'],
#   'Hydrogen': [27, 'body'],
#   'Ocean': [27, 'body'],
#   'Nitrogen': [30, 'body'],
#   'Oxygen': [30, 'body'],
#   'Radio': [32, 'body']},
#  'Comet_Shoemaker-Levy_9': {'Comet': [0, 'lead'],
#   'Jupiter': [0, 'lead'],
#   'Solar_system': [0, 'lead'],
#   'Astronomy': [0, 'lead'],
#   'California': [1, 'lead'],
#   'Sun': [1, 'lead'],
#   'Great_Red_Spot': [2, 'lead'],
#   'Gravity': [5, 'body'],
#   'Roche_limit': [10, 'body'],
#   'Alphabet': [10, 'body'],
#   'Comet_Hyakutake': [14, 'body'],
#   'Meteor': [14, 'body'],
#   'Hubble_Space_Telescope': [17, 'body'],
#   'Sulfur': [24, 'body'],
#   'Ammonia': [24, 'body'],
#   'Oxygen': [24, 'body'],
#   'Atom': [25, 'body'],
#   'Iron': [25, 'body'],
#   'Magnesium': [25, 'body'],
#   'Silicon': [25, 'body'],
#   'Radio': [29, 'body'],
#   'Electron': [29, 'body'],
#   'Volcano': [31, 'body'],
#   'Moon': [42, 'body'],
#   'Asteroid': [44, 'body'],
#   'Dinosaur': [46, 'body'],
#   'Cretaceous': [46, 'body']},
#  'Comet_White-Ortiz-Bolelli': {'Comet': [0, 'lead'],
#   'Australia': [2, 'body'],
#   'Binoculars': [2, 'body'],
#   'Star': [2, 'body'],
#   'Madagascar': [3, 'body'],
#   'Chile': [3, 'body'],
#   'Earth': [5, 'body'],
#   'Moon': [6, 'body'],
#   'Sun': [9, 'body'],
#   'Solar_eclipse': [9, 'body']},
#  'Comics': {'Newspaper': [1, 'lead'],
#   'Europe': [2, 'lead'],
#   'Animation': [10, 'body'],
#   'Stained_glass': [12, 'body'],
#   'William_Hogarth': [16, 'body'],
#   'Palace_of_Westminster': [22, 'body'],
#   'China': [24, 'body'],
#   'Humour': [28, 'body'],
#   'The_Adventures_of_Tintin': [29, 'body'],
#   'Belgium': [29, 'body'],
#   'Superman': [33, 'body'],
#   'World_War_II': [34, 'body'],
#   'Graphic_novel': [36, 'body'],
#   'Brush': [40, 'body'],
#   'Literature': [48, 'body'],
#   'Art': [48, 'body'],
#   'Film': [49, 'body'],
#   'United_Kingdom': [56, 'body'],
#   'United_States': [56, 'body'],
#   'The_Dandy': [62, 'body'],
#   'The_Beano': [62, 'body'],
#   'World_Wide_Web': [71, 'body'],
#   'Publishing': [71, 'body'],
#   'Watercolor_painting': [92, 'body'],
#   'Brussels': [116, 'body']},
#  'Comma_Johanneum': {'Trinity': [1, 'lead'],
#   'Jesus': [1, 'lead'],
#   'Augustine_of_Hippo': [4, 'body'],
#   '10th_century': [6, 'body'],
#   '6th_century': [7, 'body'],
#   'Humanism': [9, 'body'],
#   'Martin_Luther': [9, 'body'],
#   'Hebrew_language': [10, 'body'],
#   'Basel': [11, 'body'],
#   'German_language': [11, 'body'],
#   'Oxford': [14, 'body'],
#   'Isaac_Newton': [16, 'body'],
#   'Mathematics': [16, 'body'],
#   'Physics': [16, 'body'],
#   'John_Locke': [16, 'body'],
#   'French_language': [18, 'body'],
#   'Roman_Catholic_Church': [19, 'body'],
#   '19th_century': [23, 'body']},
#  'Commodore_64': {'United_States_dollar': [0, 'lead'],
#   'Integrated_circuit': [5, 'body'],
#   'United_States': [12, 'body'],
#   'United_Kingdom': [17, 'body'],
#   'Sinclair_Research_Ltd': [17, 'body'],
#   'ZX_Spectrum': [17, 'body'],
#   'Germany': [18, 'body'],
#   'ASCII': [39, 'body'],
#   'Computer_and_video_games': [39, 'body'],
#   'Radio_frequency': [46, 'body'],
#   'Europe': [46, 'body'],
#   'Microsoft': [55, 'body']},
#  'Common_Basilisk': {'South_America': [0, 'lead'],
#   'Insect': [0, 'lead'],
#   'Invertebrate': [0, 'lead'],
#   'Bird': [0, 'lead'],
#   'Fish': [0, 'lead']},
#  'Common_Cuckoo': {'Bird': [0, 'lead'],
#   'Bird_migration': [2, 'lead'],
#   'Europe': [2, 'lead'],
#   'Asia': [2, 'lead'],
#   'Africa': [2, 'lead'],
#   'Dunnock': [2, 'lead'],
#   'Reed_Warbler': [2, 'lead'],
#   'Bird_of_prey': [3, 'lead'],
#   'Insect': [3, 'lead'],
#   'Edward_Jenner': [8, 'body']},
#  'Common_Eider': {'Europe': [6, 'lead'],
#   'North_America': [6, 'lead'],
#   'Arctic': [6, 'lead'],
#   'Bird_migration': [6, 'lead'],
#   'Temperate': [6, 'lead'],
#   'Bird': [8, 'lead']},
#  'Common_Eland': {'Antelope': [0, 'lead'],
#   'East_Africa': [0, 'lead'],
#   'Southern_Africa': [0, 'lead'],
#   'Giant_Eland': [1, 'lead']},
#  'Common_Hazel': {'Europe': [0, 'lead'],
#   'Asia': [0, 'lead'],
#   'Flower': [1, 'lead'],
#   'Fruit': [1, 'lead'],
#   'Italy': [3, 'lead'],
#   'England': [5, 'body'],
#   'Wood': [5, 'body'],
#   'Turkey': [6, 'body'],
#   'China': [6, 'body'],
#   'Australia': [6, 'body'],
#   'Seed': [6, 'body'],
#   'United_States': [7, 'body'],
#   'Oregon': [7, 'body'],
#   'Canada': [7, 'body'],
#   'California': [7, 'body'],
#   'Chocolate': [8, 'body'],
#   'Austria': [9, 'body'],
#   'Coffee': [10, 'body'],
#   'Butter': [11, 'body'],
#   'Protein': [14, 'body'],
#   'Thiamine': [14, 'body'],
#   'Cultivar': [15, 'body']},
#  'Common_Pheasant': {'Feather': [1, 'lead'],
#   'Invertebrate': [3, 'lead'],
#   'United_States': [6, 'lead'],
#   'United_Kingdom': [6, 'lead'],
#   'Extinction': [7, 'lead'],
#   'North_America': [7, 'lead'],
#   'Japan': [9, 'lead']},
#  'Common_Tern': {'Tern': [0, 'lead'],
#   'Bird': [0, 'lead'],
#   'Europe': [0, 'lead'],
#   'Asia': [0, 'lead'],
#   'North_America': [0, 'lead'],
#   'Bird_migration': [0, 'lead'],
#   'Arctic_Tern': [4, 'lead'],
#   'Scotland': [7, 'lead'],
#   'Canada': [7, 'lead']},
#  'Common_agouti': {'Sugarcane': [4, 'lead'],
#   'Banana': [4, 'lead'],
#   'Rainforest': [4, 'lead']},
#  'Common_cold': {'Pneumonia': [1, 'lead'],
#   'Cell_%28biology%29': [8, 'body'],
#   'Bacterium': [14, 'body'],
#   'Tobacco_smoking': [17, 'body'],
#   'Vitamin_C': [33, 'body'],
#   'Linus_Pauling': [33, 'body'],
#   'Zinc': [39, 'body'],
#   'Chemistry': [40, 'body'],
#   'Copper': [41, 'body'],
#   'Anemia': [41, 'body'],
#   'United_States': [42, 'body'],
#   'United_Kingdom': [42, 'body'],
#   'Lemon': [47, 'body'],
#   'Soup': [47, 'body'],
#   'Ancient_Egypt': [57, 'body'],
#   'Hippocrates': [57, 'body'],
#   'Aztec': [57, 'body'],
#   'Maya_civilization': [57, 'body'],
#   'Honey': [57, 'body'],
#   'Tobacco': [57, 'body'],
#   '18th_century': [58, 'body'],
#   '19th_century': [58, 'body'],
#   'Virus': [60, 'body'],
#   'Germany': [60, 'body'],
#   'Chimpanzee': [60, 'body'],
#   'Iceland': [65, 'body'],
#   'Greenland': [65, 'body']},
#  'Common_sage': {'Europe': [0, 'lead'],
#   'Mediterranean': [0, 'lead'],
#   'Essential_oil': [3, 'lead'],
#   'Cultivar': [4, 'lead'],
#   'Martin_Luther': [5, 'lead'],
#   'Cheese': [7, 'body'],
#   'Onion': [7, 'body'],
#   'Soup': [7, 'body'],
#   'Middle_East': [7, 'body']},
#  'Commonwealth_Games': {'Netball': [2, 'lead'],
#   'United_Kingdom': [3, 'lead'],
#   'England': [3, 'lead'],
#   'Scotland': [3, 'lead'],
#   'Wales': [3, 'lead'],
#   'Northern_Ireland': [3, 'lead'],
#   'Guernsey': [3, 'lead'],
#   'Jersey': [3, 'lead'],
#   'Isle_of_Man': [3, 'lead'],
#   'Australia': [3, 'lead'],
#   'Norfolk_Island': [3, 'lead'],
#   'Cook_Islands': [3, 'lead'],
#   'Niue': [3, 'lead'],
#   'New_Zealand': [3, 'lead'],
#   'Canada': [4, 'lead'],
#   'British_Empire': [6, 'body'],
#   'London': [7, 'body'],
#   'George_V_of_the_United_Kingdom': [7, 'body'],
#   'Nigeria': [11, 'body'],
#   'South_Africa': [11, 'body'],
#   'Margaret_Thatcher': [11, 'body'],
#   'Tokelau': [23, 'body'],
#   'Turkish_Republic_of_Northern_Cyprus': [23, 'body']},
#  'Communication': {'Information': [0, 'lead'],
#   'Language': [0, 'lead'],
#   'Ludwig_Wittgenstein': [1, 'lead'],
#   'Writing': [3, 'lead'],
#   'Mass_media': [7, 'lead'],
#   'Human': [11, 'body'],
#   'Sound': [12, 'body'],
#   'Esperanto': [14, 'body'],
#   'Electromagnetic_wave': [15, 'body'],
#   'Television': [15, 'body'],
#   'Radio': [15, 'body'],
#   'Telephone': [15, 'body'],
#   'Internet': [15, 'body']},
#  'Communism': {'Marxism': [1, 'lead'],
#   'Socialism': [3, 'lead'],
#   'Capitalism': [3, 'lead'],
#   'Cold_War': [3, 'lead'],
#   'Karl_Marx': [4, 'lead'],
#   'Vladimir_Lenin': [4, 'lead'],
#   'Leon_Trotsky': [4, 'lead'],
#   'Che_Guevara': [4, 'lead'],
#   'Human': [5, 'lead'],
#   'Soviet_Union': [5, 'lead'],
#   'Europe': [7, 'lead'],
#   'Russian_Revolution_of_1917': [7, 'lead'],
#   'World_War_II': [8, 'lead'],
#   'Mao_Zedong': [8, 'lead'],
#   'People%27s_Republic_of_China': [8, 'lead'],
#   'Cuba': [8, 'lead'],
#   'North_Korea': [8, 'lead'],
#   'Laos': [8, 'lead'],
#   'Angola': [8, 'lead'],
#   'Mozambique': [8, 'lead'],
#   'France': [9, 'lead'],
#   'Italy': [9, 'lead'],
#   'South_America': [10, 'lead'],
#   'Plato': [14, 'body'],
#   'Thomas_More': [16, 'body'],
#   'Oliver_Cromwell': [16, 'body'],
#   'Robert_Owen': [18, 'body'],
#   'Industrial_Revolution': [19, 'body'],
#   'Manchester': [19, 'body'],
#   'World_War_I': [34, 'body'],
#   'Joseph_Stalin': [36, 'body'],
#   'Ukraine': [39, 'body'],
#   'Spain': [39, 'body'],
#   'Latin_America': [46, 'body'],
#   'Asia': [46, 'body'],
#   'Argentina': [46, 'body'],
#   'Brazil': [46, 'body'],
#   'Mexico': [46, 'body'],
#   'Sri_Lanka': [46, 'body'],
#   'The_Philippines': [46, 'body'],
#   'North_America': [46, 'body'],
#   'Bulgaria': [58, 'body'],
#   'Poland': [58, 'body'],
#   'Hungary': [58, 'body'],
#   'Romania': [58, 'body'],
#   'Yugoslavia': [58, 'body'],
#   'Albania': [58, 'body'],
#   'Middle_East': [59, 'body'],
#   'Africa': [59, 'body'],
#   'Vietnam': [59, 'body'],
#   'Vietnam_War': [59, 'body'],
#   'Nationalism': [59, 'body'],
#   'Mikhail_Gorbachev': [61, 'body'],
#   'Moldova': [62, 'body'],
#   'India': [62, 'body'],
#   'Nepal': [66, 'body'],
#   'Philippines': [66, 'body'],
#   'Colombia': [66, 'body'],
#   'Karl_Popper': [68, 'body']},
#  'Community': {'Plant': [0, 'lead'],
#   'Animal': [0, 'lead'],
#   'Human': [0, 'lead'],
#   'Latin': [1, 'lead'],
#   'Society': [5, 'body'],
#   'Social_capital': [11, 'body'],
#   '20th_century': [26, 'body'],
#   'Capitalism': [26, 'body'],
#   'Civil_society': [26, 'body'],
#   'Multiculturalism': [26, 'body'],
#   'Communication': [29, 'body'],
#   'Culture': [32, 'body'],
#   'University_of_Chicago': [36, 'body'],
#   'United_States': [36, 'body'],
#   'United_Kingdom': [36, 'body'],
#   'New_York_City': [39, 'body'],
#   'September_11%2C_2001_attacks': [39, 'body'],
#   'Local_community': [53, 'body']},
#  'Comoros': {'French_language': [0, 'lead'],
#   'Arabic_language': [0, 'lead'],
#   'Indian_Ocean': [0, 'lead'],
#   'Madagascar': [0, 'lead'],
#   'Mozambique': [0, 'lead'],
#   'Mayotte': [1, 'lead'],
#   'France': [1, 'lead'],
#   'Africa': [4, 'body'],
#   'Persian_Gulf': [4, 'body'],
#   'Indonesia': [4, 'body'],
#   'Portugal': [4, 'body'],
#   'African_Union': [7, 'body'],
#   'Volcano': [9, 'body'],
#   'Government': [12, 'body'],
#   'Law': [13, 'body'],
#   'United_Nations': [16, 'body'],
#   'Arab_League': [17, 'body'],
#   'Agriculture': [21, 'body'],
#   'Fishing': [21, 'body'],
#   'Vanilla': [22, 'body'],
#   'Tourism': [23, 'body'],
#   'Islam': [26, 'body'],
#   'Latin_alphabet': [27, 'body']},
#  ...}

# %%
# Procuding statistics about the position of the links in the HTML pages.
counter = [0 for i in range(400)]
classes = [0, 0]
for key in page_pos_dict.keys():
    for link in page_pos_dict[key]:
        counter[page_pos_dict[key][link][0]] += 1
        if page_pos_dict[key][link][1] == "lead":
            classes[0] += 1
        else:
            classes[1] += 1

total_links = sum(counter)
lead_links_p = round((np.array(classes) / total_links * 100)[0])
body_links_p = round((np.array(classes) / total_links * 100)[1])

print(
    "Out of total",
    total_links,
    "links,",
    lead_links_p,
    "% are in the lead section, while",
    body_links_p,
    "% are in the body section",
)
# Out:
# Out of total 99128 links, 21 % are in the lead section, while 79 % are in the body section

# %%
# Plotting the number of links vs their corresponding paragraph
plt.scatter([i for i in range(80)], counter[0:80])
plt.ylabel("Number of links")
plt.xlabel("Link Paragraph location")
plt.title("Scatter of the number of links with the paragraphs they belong")
plt.rcParams["font.size"] = "12"

plt.show()

# %%
# Analysis of links in wikispeedia games
finished_paths = pd.read_csv(
    "./data/graph/paths_finished.tsv", sep="\t", skiprows=16, header=None
)

# Parse and store the paths removing back tracks (<).
paths = []
for path in finished_paths[3]:
    if "<" not in path:
        path = path.split(";")
        for i in range(len(path) - 1):
            paths.append(path)

# %%
# For each click of the players, we store the paragraph number of
# the chosen link and the average paragraph number of all the links in the page
chosen_pars = []
avg_pars = []
chosen_labels = []
for path in paths:
    for i, article in enumerate(path):
        if i < len(path) - 1:
            source = article
            target = path[i + 1]
            if (
                target in page_pos_dict[source].keys()
            ):  # some links are missing from the dictionary, around 10%, these are the links that are not inside paragraph elements in html
                par_chosen = page_pos_dict[source][target][0]
                avg_par = sum(i for i, j in page_pos_dict[source].values()) / len(
                    page_pos_dict[source]
                )
                chosen_pars.append(par_chosen)
                avg_pars.append(avg_par)
                chosen_labels.append(page_pos_dict[source][target][1])

# %%
# Checking the size of the result
len(chosen_pars)
# Out:
# 1045196

# %%
# Histogram comparing the average paragraphs of the
# links versus the paragraphs of the links chosen by the players

plt.hist(avg_pars, range=[0, 100], alpha=0.7, color="r", bins=30, label="Expected")
plt.xlabel("Paragraph number")
plt.ylabel("Number of clicks")
plt.title("Expected paragraph clicks if links were chosen randomly vs Observed clicks")
plt.hist(chosen_pars, range=[0, 100], alpha=0.7, color="b", bins=30, label="Observed")
plt.legend()
plt.show()

# %%
# Number of clicks in the lead section and the body section. We observe although
# just 20% of the total links are located in the lead section,
# they are chosen by the players more than 40% of the time.

label_enc = [0 if label == "lead" else 1 for label in chosen_labels]

body_clicks = sum(label_enc)
lead_clicks = len(label_enc) - body_clicks

fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_ylabel("Number of clicks")
ax1.set_xlabel("Click Location")
ax1.bar(["lead", "body"], [lead_clicks, body_clicks])
ax2.bar(["lead", "body"], classes)
ax2.set_xlabel("Link Location")
ax2.set_ylabel("Number of links")

fig.tight_layout()
plt.show()
